# %% [markdown]
# Importing needed libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the dataset

# %%
data = pd.read_csv(r"fifa_players.csv")
data.T
# Out:
#                                                         0      \
# name                                                 L. Messi
# full_name                      Lionel Andrés Messi Cuccittini
# birth_date                                          6/24/1987
# age                                                        31
# height_cm                                              170.18
# weight_kgs                                               72.1
# positions                                            CF,RW,ST
# nationality                                         Argentina
# overall_rating                                             94
# potential                                                  94
# value_euro                                        110500000.0
# wage_euro                                            565000.0
# preferred_foot                                           Left
# international_reputation(1-5)                               5
# weak_foot(1-5)                                              4
# skill_moves(1-5)                                            4
# body_type                                               Messi
# release_clause_euro                               226500000.0
# national_team                                       Argentina
# national_rating                                          82.0
# national_team_position                                     RF
# national_jersey_number                                   10.0
# crossing                                                   86
# finishing                                                  95
# heading_accuracy                                           70
# short_passing                                              92
# volleys                                                    86
# dribbling                                                  97
# curve                                                      93
# freekick_accuracy                                          94
# long_passing                                               89
# ball_control                                               96
# acceleration                                               91
# sprint_speed                                               86
# agility                                                    93
# reactions                                                  95
# balance                                                    95
# shot_power                                                 85
# jumping                                                    68
# stamina                                                    72
# strength                                                   66
# long_shots                                                 94
# aggression                                                 48
# interceptions                                              22
# positioning                                                94
# vision                                                     94
# penalties                                                  75
# composure                                                  96
# marking                                                    33
# standing_tackle                                            28
# sliding_tackle                                             26
#
#                                                       1            2      \
# name                                             C. Eriksen     P. Pogba
# full_name                      Christian  Dannemann Eriksen   Paul Pogba
# birth_date                                        2/14/1992    3/15/1993
# age                                                      27           25
# height_cm                                            154.94        190.5
# weight_kgs                                             76.2         83.9
# positions                                         CAM,RM,CM       CM,CAM
# nationality                                         Denmark       France
# overall_rating                                           88           88
# potential                                                89           91
# value_euro                                       69500000.0   73000000.0
# wage_euro                                          205000.0     255000.0
# preferred_foot                                        Right        Right
# international_reputation(1-5)                             3            4
# weak_foot(1-5)                                            5            4
# skill_moves(1-5)                                          4            5
# body_type                                              Lean       Normal
# release_clause_euro                             133800000.0  144200000.0
# national_team                                       Denmark       France
# national_rating                                        78.0         84.0
# national_team_position                                  CAM          RDM
# national_jersey_number                                 10.0          6.0
# crossing                                                 88           80
# finishing                                                81           75
# heading_accuracy                                         52           75
# short_passing                                            91           86
# volleys                                                  80           85
# dribbling                                                84           87
# curve                                                    86           85
# freekick_accuracy                                        87           82
# long_passing                                             89           90
# ball_control                                             91           90
# acceleration                                             76           71
# sprint_speed                                             73           79
# agility                                                  80           76
# reactions                                                88           82
# balance                                                  81           66
# shot_power                                               84           90
# jumping                                                  50           83
# stamina                                                  92           88
# strength                                                 58           87
# long_shots                                               89           82
# aggression                                               46           78
# interceptions                                            56           64
# positioning                                              84           82
# vision                                                   91           88
# penalties                                                67           82
# composure                                                88           87
# marking                                                  59           63
# standing_tackle                                          57           67
# sliding_tackle                                           22           67
#
#                                          3                  4      \
# name                                L. Insigne       K. Koulibaly
# full_name                      Lorenzo Insigne  Kalidou Koulibaly
# birth_date                            6/4/1991          6/20/1991
# age                                         27                 27
# height_cm                               162.56             187.96
# weight_kgs                                59.0               88.9
# positions                                LW,ST                 CB
# nationality                              Italy            Senegal
# overall_rating                              88                 88
# potential                                   88                 91
# value_euro                          62000000.0         60000000.0
# wage_euro                             165000.0           135000.0
# preferred_foot                           Right              Right
# international_reputation(1-5)                3                  3
# weak_foot(1-5)                               4                  3
# skill_moves(1-5)                             4                  2
# body_type                               Normal             Normal
# release_clause_euro                105400000.0        106500000.0
# national_team                            Italy                NaN
# national_rating                           83.0                NaN
# national_team_position                      LW                NaN
# national_jersey_number                    10.0                NaN
# crossing                                    86                 30
# finishing                                   77                 22
# heading_accuracy                            56                 83
# short_passing                               85                 68
# volleys                                     74                 14
# dribbling                                   90                 69
# curve                                       87                 28
# freekick_accuracy                           77                 28
# long_passing                                78                 60
# ball_control                                93                 63
# acceleration                                94                 70
# sprint_speed                                86                 75
# agility                                     94                 50
# reactions                                   83                 82
# balance                                     93                 40
# shot_power                                  75                 55
# jumping                                     53                 81
# stamina                                     75                 75
# strength                                    44                 94
# long_shots                                  84                 15
# aggression                                  34                 87
# interceptions                               26                 88
# positioning                                 83                 24
# vision                                      87                 49
# penalties                                   61                 33
# composure                                   83                 80
# marking                                     51                 91
# standing_tackle                             24                 88
# sliding_tackle                              22                 87
#
#                                          5              6      \
# name                               V. van Dijk      K. Mbappé
# full_name                      Virgil van Dijk  Kylian Mbappé
# birth_date                            7/8/1991     12/20/1998
# age                                         27             20
# height_cm                               193.04          152.4
# weight_kgs                                92.1           73.0
# positions                                   CB       RW,ST,RM
# nationality                        Netherlands         France
# overall_rating                              88             88
# potential                                   90             95
# value_euro                          59500000.0     81000000.0
# wage_euro                             215000.0       100000.0
# preferred_foot                           Right          Right
# international_reputation(1-5)                3              3
# weak_foot(1-5)                               3              4
# skill_moves(1-5)                             2              5
# body_type                               Normal           Lean
# release_clause_euro                114500000.0    166100000.0
# national_team                      Netherlands         France
# national_rating                           81.0           84.0
# national_team_position                     LCB             RM
# national_jersey_number                     4.0           10.0
# crossing                                    53             77
# finishing                                   52             88
# heading_accuracy                            83             77
# short_passing                               79             82
# volleys                                     45             78
# dribbling                                   70             90
# curve                                       60             77
# freekick_accuracy                           70             63
# long_passing                                81             73
# ball_control                                76             91
# acceleration                                74             96
# sprint_speed                                77             96
# agility                                     61             92
# reactions                                   87             87
# balance                                     49             83
# shot_power                                  81             79
# jumping                                     88             75
# stamina                                     75             83
# strength                                    92             71
# long_shots                                  64             78
# aggression                                  82             62
# interceptions                               88             38
# positioning                                 41             88
# vision                                      60             82
# penalties                                   62             70
# composure                                   87             86
# marking                                     90             34
# standing_tackle                             89             34
# sliding_tackle                              84             32
#
#                                                            7      \
# name                                                   S. Agüero
# full_name                      Sergio Leonel Agüero del Castillo
# birth_date                                              6/2/1988
# age                                                           30
# height_cm                                                 172.72
# weight_kgs                                                  69.9
# positions                                                     ST
# nationality                                            Argentina
# overall_rating                                                89
# potential                                                     89
# value_euro                                            64500000.0
# wage_euro                                               300000.0
# preferred_foot                                             Right
# international_reputation(1-5)                                  4
# weak_foot(1-5)                                                 4
# skill_moves(1-5)                                               4
# body_type                                                 Stocky
# release_clause_euro                                  119300000.0
# national_team                                          Argentina
# national_rating                                             82.0
# national_team_position                                       SUB
# national_jersey_number                                      11.0
# crossing                                                      70
# finishing                                                     93
# heading_accuracy                                              77
# short_passing                                                 81
# volleys                                                       85
# dribbling                                                     89
# curve                                                         82
# freekick_accuracy                                             73
# long_passing                                                  64
# ball_control                                                  89
# acceleration                                                  88
# sprint_speed                                                  80
# agility                                                       86
# reactions                                                     90
# balance                                                       91
# shot_power                                                    88
# jumping                                                       81
# stamina                                                       76
# strength                                                      73
# long_shots                                                    83
# aggression                                                    65
# interceptions                                                 24
# positioning                                                   92
# vision                                                        83
# penalties                                                     83
# composure                                                     90
# marking                                                       30
# standing_tackle                                               20
# sliding_tackle                                                12
#
#                                       8                             9      \
# name                               M. Neuer                     E. Cavani
# full_name                      Manuel Neuer  Edinson Roberto Cavani Gómez
# birth_date                        3/27/1986                     2/14/1987
# age                                      32                            32
# height_cm                            193.04                        185.42
# weight_kgs                             92.1                          77.1
# positions                                GK                            ST
# nationality                         Germany                       Uruguay
# overall_rating                           89                            89
# potential                                89                            89
# value_euro                       38000000.0                    60000000.0
# wage_euro                          130000.0                      200000.0
# preferred_foot                        Right                         Right
# international_reputation(1-5)             5                             4
# weak_foot(1-5)                            4                             4
# skill_moves(1-5)                          1                             3
# body_type                            Normal                          Lean
# release_clause_euro              62700000.0                   111000000.0
# national_team                       Germany                       Uruguay
# national_rating                        85.0                          81.0
# national_team_position                   GK                            LS
# national_jersey_number                  1.0                          21.0
# crossing                                 15                            70
# finishing                                13                            89
# heading_accuracy                         25                            89
# short_passing                            55                            78
# volleys                                  11                            90
# dribbling                                30                            80
# curve                                    14                            77
# freekick_accuracy                        11                            76
# long_passing                             59                            52
# ball_control                             46                            82
# acceleration                             54                            75
# sprint_speed                             60                            76
# agility                                  51                            77
# reactions                                84                            91
# balance                                  35                            59
# shot_power                               25                            87
# jumping                                  77                            88
# stamina                                  43                            92
# strength                                 80                            78
# long_shots                               16                            79
# aggression                               29                            84
# interceptions                            30                            48
# positioning                              12                            93
# vision                                   70                            77
# penalties                                47                            85
# composure                                70                            82
# marking                                  17                            52
# standing_tackle                          10                            45
# sliding_tackle                           11                            39
#
#                                ...                                17944  \
# name                           ...                    Cristiano Ronaldo
# full_name                      ...  Cristiano Ronaldo dos Santos Aveiro
# birth_date                     ...                             2/5/1985
# age                            ...                                   34
# height_cm                      ...                               187.96
# weight_kgs                     ...                                 83.0
# positions                      ...                                ST,LW
# nationality                    ...                             Portugal
# overall_rating                 ...                                   94
# potential                      ...                                   94
# value_euro                     ...                           77000000.0
# wage_euro                      ...                             405000.0
# preferred_foot                 ...                                Right
# international_reputation(1-5)  ...                                    5
# weak_foot(1-5)                 ...                                    4
# skill_moves(1-5)               ...                                    5
# body_type                      ...                           C. Ronaldo
# release_clause_euro            ...                          127100000.0
# national_team                  ...                             Portugal
# national_rating                ...                                 82.0
# national_team_position         ...                                   ST
# national_jersey_number         ...                                  7.0
# crossing                       ...                                   84
# finishing                      ...                                   94
# heading_accuracy               ...                                   89
# short_passing                  ...                                   81
# volleys                        ...                                   87
# dribbling                      ...                                   88
# curve                          ...                                   81
# freekick_accuracy              ...                                   76
# long_passing                   ...                                   77
# ball_control                   ...                                   94
# acceleration                   ...                                   89
# sprint_speed                   ...                                   91
# agility                        ...                                   87
# reactions                      ...                                   96
# balance                        ...                                   70
# shot_power                     ...                                   95
# jumping                        ...                                   95
# stamina                        ...                                   88
# strength                       ...                                   79
# long_shots                     ...                                   93
# aggression                     ...                                   63
# interceptions                  ...                                   29
# positioning                    ...                                   95
# vision                         ...                                   82
# penalties                      ...                                   85
# composure                      ...                                   95
# marking                        ...                                   28
# standing_tackle                ...                                   31
# sliding_tackle                 ...                                   23
#
#                                           17945            17946  \
# name                                   J. Serra     A. Rodriguez
# full_name                      Janni-Luca Serra  Angel Rodriguez
# birth_date                            3/13/1998        12/2/1992
# age                                          20               26
# height_cm                                193.04           175.26
# weight_kgs                                 87.1             72.1
# positions                                    ST            CM,CB
# nationality                             Germany          Uruguay
# overall_rating                               67               67
# potential                                    79               67
# value_euro                            1400000.0         825000.0
# wage_euro                                4000.0           1000.0
# preferred_foot                             Left            Right
# international_reputation(1-5)                 1                1
# weak_foot(1-5)                                4                3
# skill_moves(1-5)                              2                3
# body_type                                Normal           Normal
# release_clause_euro                   2500000.0        1100000.0
# national_team                               NaN              NaN
# national_rating                             NaN              NaN
# national_team_position                      NaN              NaN
# national_jersey_number                      NaN              NaN
# crossing                                     41               58
# finishing                                    66               54
# heading_accuracy                             73               59
# short_passing                                57               73
# volleys                                      65               51
# dribbling                                    57               68
# curve                                        43               56
# freekick_accuracy                            28               49
# long_passing                                 28               72
# ball_control                                 65               65
# acceleration                                 53               66
# sprint_speed                                 65               66
# agility                                      48               57
# reactions                                    57               60
# balance                                      34               71
# shot_power                                   74               70
# jumping                                      64               62
# stamina                                      62               69
# strength                                     84               76
# long_shots                                   59               56
# aggression                                   65               72
# interceptions                                23               65
# positioning                                  69               60
# vision                                       45               60
# penalties                                    50               55
# composure                                    49               52
# marking                                      35               63
# standing_tackle                              38               64
# sliding_tackle                               33               67
#
#                                        17947                       17948  \
# name                              A. Calisir                   R. Torres
# full_name                      André Calisir  Róger Mauricio Torres Hoya
# birth_date                         6/13/1990                   7/13/1991
# age                                       28                          27
# height_cm                             154.94                      170.18
# weight_kgs                              73.9                        67.1
# positions                                 CB                         CAM
# nationality                          Armenia                    Colombia
# overall_rating                            67                          67
# potential                                 69                          68
# value_euro                          725000.0                    900000.0
# wage_euro                             2000.0                      1000.0
# preferred_foot                         Right                        Left
# international_reputation(1-5)              1                           1
# weak_foot(1-5)                             3                           3
# skill_moves(1-5)                           2                           3
# body_type                             Normal                      Normal
# release_clause_euro                 961000.0                         NaN
# national_team                            NaN                         NaN
# national_rating                          NaN                         NaN
# national_team_position                   NaN                         NaN
# national_jersey_number                   NaN                         NaN
# crossing                                  48                          68
# finishing                                 25                          57
# heading_accuracy                          58                          52
# short_passing                             59                          64
# volleys                                   28                          57
# dribbling                                 47                          68
# curve                                     42                          70
# freekick_accuracy                         22                          68
# long_passing                              60                          61
# ball_control                              57                          65
# acceleration                              59                          81
# sprint_speed                              58                          81
# agility                                   64                          91
# reactions                                 55                          53
# balance                                   61                          89
# shot_power                                44                          70
# jumping                                   86                          71
# stamina                                   65                          65
# strength                                  72                          34
# long_shots                                27                          65
# aggression                                82                          45
# interceptions                             62                          32
# positioning                               38                          55
# vision                                    53                          72
# penalties                                 56                          64
# composure                                 64                          62
# marking                                   67                          51
# standing_tackle                           68                          38
# sliding_tackle                            68                          17
#
#                                         17949          17950        17951  \
# name                              R. McKenzie      M. Sipľak   J. Bekkema
# full_name                      Rory  McKenzie  Michal Sipľak  Jan Bekkema
# birth_date                          10/7/1993       2/2/1996     4/9/1996
# age                                        25             23           22
# height_cm                              175.26         182.88       185.42
# weight_kgs                               74.8           79.8         89.8
# positions                           RM,CAM,CM             LB           GK
# nationality                          Scotland       Slovakia  Netherlands
# overall_rating                             67             59           59
# potential                                  70             67           67
# value_euro                           975000.0       190000.0     170000.0
# wage_euro                              3000.0         1000.0       1000.0
# preferred_foot                          Right           Left        Right
# international_reputation(1-5)               1              1            1
# weak_foot(1-5)                              3              3            1
# skill_moves(1-5)                            3              2            1
# body_type                              Normal         Normal       Normal
# release_clause_euro                 1800000.0       295000.0     289000.0
# national_team                             NaN            NaN          NaN
# national_rating                           NaN            NaN          NaN
# national_team_position                    NaN            NaN          NaN
# national_jersey_number                    NaN            NaN          NaN
# crossing                                   57             50           11
# finishing                                  61             19            9
# heading_accuracy                           60             53           13
# short_passing                              66             55           26
# volleys                                    37             31            9
# dribbling                                  64             52           12
# curve                                      53             26           13
# freekick_accuracy                          47             28           12
# long_passing                               61             43           24
# ball_control                               66             53           18
# acceleration                               83             70           27
# sprint_speed                               86             64           22
# agility                                    93             54           29
# reactions                                  63             50           48
# balance                                    82             53           38
# shot_power                                 51             27           17
# jumping                                    77             74           43
# stamina                                    75             66           25
# strength                                   64             70           63
# long_shots                                 54             22            9
# aggression                                 69             62           27
# interceptions                              41             55           10
# positioning                                60             42            5
# vision                                     64             39           25
# penalties                                  63             32           16
# composure                                  56             52           47
# marking                                    40             53            9
# standing_tackle                            20             64           12
# sliding_tackle                             18             60           13
#
#                                              17952  \
# name                                    A. Al Yami
# full_name                      Abdulrahman Al Yami
# birth_date                               6/19/1997
# age                                             21
# height_cm                                   175.26
# weight_kgs                                    64.9
# positions                                    ST,LM
# nationality                           Saudi Arabia
# overall_rating                                  59
# potential                                       71
# value_euro                                280000.0
# wage_euro                                   4000.0
# preferred_foot                               Right
# international_reputation(1-5)                    1
# weak_foot(1-5)                                   4
# skill_moves(1-5)                                 3
# body_type                                     Lean
# release_clause_euro                       532000.0
# national_team                                  NaN
# national_rating                                NaN
# national_team_position                         NaN
# national_jersey_number                         NaN
# crossing                                        42
# finishing                                       60
# heading_accuracy                                55
# short_passing                                   49
# volleys                                         49
# dribbling                                       57
# curve                                           47
# freekick_accuracy                               39
# long_passing                                    37
# ball_control                                    56
# acceleration                                    84
# sprint_speed                                    86
# agility                                         65
# reactions                                       53
# balance                                         73
# shot_power                                      56
# jumping                                         58
# stamina                                         58
# strength                                        49
# long_shots                                      58
# aggression                                      38
# interceptions                                   15
# positioning                                     54
# vision                                          52
# penalties                                       50
# composure                                       53
# marking                                         16
# standing_tackle                                 18
# sliding_tackle                                  17
#
#                                                           17953
# name                                             Júnior Brumado
# full_name                      José Francisco dos Santos Júnior
# birth_date                                            5/15/1999
# age                                                          19
# height_cm                                                 190.5
# weight_kgs                                                 79.8
# positions                                                    ST
# nationality                                              Brazil
# overall_rating                                               59
# potential                                                    75
# value_euro                                             325000.0
# wage_euro                                                2000.0
# preferred_foot                                            Right
# international_reputation(1-5)                                 1
# weak_foot(1-5)                                                4
# skill_moves(1-5)                                              2
# body_type                                                Normal
# release_clause_euro                                    626000.0
# national_team                                               NaN
# national_rating                                             NaN
# national_team_position                                      NaN
# national_jersey_number                                      NaN
# crossing                                                     32
# finishing                                                    58
# heading_accuracy                                             58
# short_passing                                                47
# volleys                                                      39
# dribbling                                                    58
# curve                                                        35
# freekick_accuracy                                            25
# long_passing                                                 37
# ball_control                                                 56
# acceleration                                                 67
# sprint_speed                                                 72
# agility                                                      71
# reactions                                                    54
# balance                                                      59
# shot_power                                                   61
# jumping                                                      60
# stamina                                                      57
# strength                                                     67
# long_shots                                                   53
# aggression                                                   67
# interceptions                                                20
# positioning                                                  53
# vision                                                       49
# penalties                                                    52
# composure                                                    45
# marking                                                      23
# standing_tackle                                              31
# sliding_tackle                                               21
#
# [51 rows x 17954 columns]

# %% [markdown]
# This dataset contains 51 columns and 17954 rows. Printing the columns.

# %%
data.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type',
#        'release_clause_euro', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
#        'composure', 'marking', 'standing_tackle', 'sliding_tackle'],
#       dtype='object')

# %% [markdown]
# Printing the info of dataset and checking missing values.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  int64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  int64
#  9   potential                      17954 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17708 non-null  float64
#  12  preferred_foot                 17954 non-null  object
#  13  international_reputation(1-5)  17954 non-null  int64
#  14  weak_foot(1-5)                 17954 non-null  int64
#  15  skill_moves(1-5)               17954 non-null  int64
#  16  body_type                      17954 non-null  object
#  17  release_clause_euro            16117 non-null  float64
#  18  national_team                  857 non-null    object
#  19  national_rating                857 non-null    float64
#  20  national_team_position         857 non-null    object
#  21  national_jersey_number         857 non-null    float64
#  22  crossing                       17954 non-null  int64
#  23  finishing                      17954 non-null  int64
#  24  heading_accuracy               17954 non-null  int64
#  25  short_passing                  17954 non-null  int64
#  26  volleys                        17954 non-null  int64
#  27  dribbling                      17954 non-null  int64
#  28  curve                          17954 non-null  int64
#  29  freekick_accuracy              17954 non-null  int64
#  30  long_passing                   17954 non-null  int64
#  31  ball_control                   17954 non-null  int64
#  32  acceleration                   17954 non-null  int64
#  33  sprint_speed                   17954 non-null  int64
#  34  agility                        17954 non-null  int64
#  35  reactions                      17954 non-null  int64
#  36  balance                        17954 non-null  int64
#  37  shot_power                     17954 non-null  int64
#  38  jumping                        17954 non-null  int64
#  39  stamina                        17954 non-null  int64
#  40  strength                       17954 non-null  int64
#  41  long_shots                     17954 non-null  int64
#  42  aggression                     17954 non-null  int64
#  43  interceptions                  17954 non-null  int64
#  44  positioning                    17954 non-null  int64
#  45  vision                         17954 non-null  int64
#  46  penalties                      17954 non-null  int64
#  47  composure                      17954 non-null  int64
#  48  marking                        17954 non-null  int64
#  49  standing_tackle                17954 non-null  int64
#  50  sliding_tackle                 17954 non-null  int64
# dtypes: float64(7), int64(35), object(9)
# memory usage: 7.0+ MB

# %% [markdown]
# Checking missing values.

# %%
data.isna().sum()
# Out:
# name                                 0
# full_name                            0
# birth_date                           0
# age                                  0
# height_cm                            0
# weight_kgs                           0
# positions                            0
# nationality                          0
# overall_rating                       0
# potential                            0
# value_euro                         255
# wage_euro                          246
# preferred_foot                       0
# international_reputation(1-5)        0
# weak_foot(1-5)                       0
# skill_moves(1-5)                     0
# body_type                            0
# release_clause_euro               1837
# national_team                    17097
# national_rating                  17097
# national_team_position           17097
# national_jersey_number           17097
# crossing                             0
# finishing                            0
# heading_accuracy                     0
# short_passing                        0
# volleys                              0
# dribbling                            0
# curve                                0
# freekick_accuracy                    0
# long_passing                         0
# ball_control                         0
# acceleration                         0
# sprint_speed                         0
# agility                              0
# reactions                            0
# balance                              0
# shot_power                           0
# jumping                              0
# stamina                              0
# strength                             0
# long_shots                           0
# aggression                           0
# interceptions                        0
# positioning                          0
# vision                               0
# penalties                            0
# composure                            0
# marking                              0
# standing_tackle                      0
# sliding_tackle                       0
# dtype: int64

# %% [markdown]
# There are missing values in 7 columns. Removing unnecessary columns

# %%
drop_columns = ['release_clause_euro','national_team','national_rating','national_team_position','national_jersey_number']

# %% [markdown]
# Dropping these columns with missing values and not needed for predicting overall rating of a player.

# %%
data.drop(drop_columns,axis=1,inplace=True)

# %%
data.T
# Out:
#                                                         0      \
# name                                                 L. Messi
# full_name                      Lionel Andrés Messi Cuccittini
# birth_date                                          6/24/1987
# age                                                        31
# height_cm                                              170.18
# weight_kgs                                               72.1
# positions                                            CF,RW,ST
# nationality                                         Argentina
# overall_rating                                             94
# potential                                                  94
# value_euro                                        110500000.0
# wage_euro                                            565000.0
# preferred_foot                                           Left
# international_reputation(1-5)                               5
# weak_foot(1-5)                                              4
# skill_moves(1-5)                                            4
# body_type                                               Messi
# crossing                                                   86
# finishing                                                  95
# heading_accuracy                                           70
# short_passing                                              92
# volleys                                                    86
# dribbling                                                  97
# curve                                                      93
# freekick_accuracy                                          94
# long_passing                                               89
# ball_control                                               96
# acceleration                                               91
# sprint_speed                                               86
# agility                                                    93
# reactions                                                  95
# balance                                                    95
# shot_power                                                 85
# jumping                                                    68
# stamina                                                    72
# strength                                                   66
# long_shots                                                 94
# aggression                                                 48
# interceptions                                              22
# positioning                                                94
# vision                                                     94
# penalties                                                  75
# composure                                                  96
# marking                                                    33
# standing_tackle                                            28
# sliding_tackle                                             26
#
#                                                       1           2      \
# name                                             C. Eriksen    P. Pogba
# full_name                      Christian  Dannemann Eriksen  Paul Pogba
# birth_date                                        2/14/1992   3/15/1993
# age                                                      27          25
# height_cm                                            154.94       190.5
# weight_kgs                                             76.2        83.9
# positions                                         CAM,RM,CM      CM,CAM
# nationality                                         Denmark      France
# overall_rating                                           88          88
# potential                                                89          91
# value_euro                                       69500000.0  73000000.0
# wage_euro                                          205000.0    255000.0
# preferred_foot                                        Right       Right
# international_reputation(1-5)                             3           4
# weak_foot(1-5)                                            5           4
# skill_moves(1-5)                                          4           5
# body_type                                              Lean      Normal
# crossing                                                 88          80
# finishing                                                81          75
# heading_accuracy                                         52          75
# short_passing                                            91          86
# volleys                                                  80          85
# dribbling                                                84          87
# curve                                                    86          85
# freekick_accuracy                                        87          82
# long_passing                                             89          90
# ball_control                                             91          90
# acceleration                                             76          71
# sprint_speed                                             73          79
# agility                                                  80          76
# reactions                                                88          82
# balance                                                  81          66
# shot_power                                               84          90
# jumping                                                  50          83
# stamina                                                  92          88
# strength                                                 58          87
# long_shots                                               89          82
# aggression                                               46          78
# interceptions                                            56          64
# positioning                                              84          82
# vision                                                   91          88
# penalties                                                67          82
# composure                                                88          87
# marking                                                  59          63
# standing_tackle                                          57          67
# sliding_tackle                                           22          67
#
#                                          3                  4      \
# name                                L. Insigne       K. Koulibaly
# full_name                      Lorenzo Insigne  Kalidou Koulibaly
# birth_date                            6/4/1991          6/20/1991
# age                                         27                 27
# height_cm                               162.56             187.96
# weight_kgs                                59.0               88.9
# positions                                LW,ST                 CB
# nationality                              Italy            Senegal
# overall_rating                              88                 88
# potential                                   88                 91
# value_euro                          62000000.0         60000000.0
# wage_euro                             165000.0           135000.0
# preferred_foot                           Right              Right
# international_reputation(1-5)                3                  3
# weak_foot(1-5)                               4                  3
# skill_moves(1-5)                             4                  2
# body_type                               Normal             Normal
# crossing                                    86                 30
# finishing                                   77                 22
# heading_accuracy                            56                 83
# short_passing                               85                 68
# volleys                                     74                 14
# dribbling                                   90                 69
# curve                                       87                 28
# freekick_accuracy                           77                 28
# long_passing                                78                 60
# ball_control                                93                 63
# acceleration                                94                 70
# sprint_speed                                86                 75
# agility                                     94                 50
# reactions                                   83                 82
# balance                                     93                 40
# shot_power                                  75                 55
# jumping                                     53                 81
# stamina                                     75                 75
# strength                                    44                 94
# long_shots                                  84                 15
# aggression                                  34                 87
# interceptions                               26                 88
# positioning                                 83                 24
# vision                                      87                 49
# penalties                                   61                 33
# composure                                   83                 80
# marking                                     51                 91
# standing_tackle                             24                 88
# sliding_tackle                              22                 87
#
#                                          5              6      \
# name                               V. van Dijk      K. Mbappé
# full_name                      Virgil van Dijk  Kylian Mbappé
# birth_date                            7/8/1991     12/20/1998
# age                                         27             20
# height_cm                               193.04          152.4
# weight_kgs                                92.1           73.0
# positions                                   CB       RW,ST,RM
# nationality                        Netherlands         France
# overall_rating                              88             88
# potential                                   90             95
# value_euro                          59500000.0     81000000.0
# wage_euro                             215000.0       100000.0
# preferred_foot                           Right          Right
# international_reputation(1-5)                3              3
# weak_foot(1-5)                               3              4
# skill_moves(1-5)                             2              5
# body_type                               Normal           Lean
# crossing                                    53             77
# finishing                                   52             88
# heading_accuracy                            83             77
# short_passing                               79             82
# volleys                                     45             78
# dribbling                                   70             90
# curve                                       60             77
# freekick_accuracy                           70             63
# long_passing                                81             73
# ball_control                                76             91
# acceleration                                74             96
# sprint_speed                                77             96
# agility                                     61             92
# reactions                                   87             87
# balance                                     49             83
# shot_power                                  81             79
# jumping                                     88             75
# stamina                                     75             83
# strength                                    92             71
# long_shots                                  64             78
# aggression                                  82             62
# interceptions                               88             38
# positioning                                 41             88
# vision                                      60             82
# penalties                                   62             70
# composure                                   87             86
# marking                                     90             34
# standing_tackle                             89             34
# sliding_tackle                              84             32
#
#                                                            7      \
# name                                                   S. Agüero
# full_name                      Sergio Leonel Agüero del Castillo
# birth_date                                              6/2/1988
# age                                                           30
# height_cm                                                 172.72
# weight_kgs                                                  69.9
# positions                                                     ST
# nationality                                            Argentina
# overall_rating                                                89
# potential                                                     89
# value_euro                                            64500000.0
# wage_euro                                               300000.0
# preferred_foot                                             Right
# international_reputation(1-5)                                  4
# weak_foot(1-5)                                                 4
# skill_moves(1-5)                                               4
# body_type                                                 Stocky
# crossing                                                      70
# finishing                                                     93
# heading_accuracy                                              77
# short_passing                                                 81
# volleys                                                       85
# dribbling                                                     89
# curve                                                         82
# freekick_accuracy                                             73
# long_passing                                                  64
# ball_control                                                  89
# acceleration                                                  88
# sprint_speed                                                  80
# agility                                                       86
# reactions                                                     90
# balance                                                       91
# shot_power                                                    88
# jumping                                                       81
# stamina                                                       76
# strength                                                      73
# long_shots                                                    83
# aggression                                                    65
# interceptions                                                 24
# positioning                                                   92
# vision                                                        83
# penalties                                                     83
# composure                                                     90
# marking                                                       30
# standing_tackle                                               20
# sliding_tackle                                                12
#
#                                       8                             9      \
# name                               M. Neuer                     E. Cavani
# full_name                      Manuel Neuer  Edinson Roberto Cavani Gómez
# birth_date                        3/27/1986                     2/14/1987
# age                                      32                            32
# height_cm                            193.04                        185.42
# weight_kgs                             92.1                          77.1
# positions                                GK                            ST
# nationality                         Germany                       Uruguay
# overall_rating                           89                            89
# potential                                89                            89
# value_euro                       38000000.0                    60000000.0
# wage_euro                          130000.0                      200000.0
# preferred_foot                        Right                         Right
# international_reputation(1-5)             5                             4
# weak_foot(1-5)                            4                             4
# skill_moves(1-5)                          1                             3
# body_type                            Normal                          Lean
# crossing                                 15                            70
# finishing                                13                            89
# heading_accuracy                         25                            89
# short_passing                            55                            78
# volleys                                  11                            90
# dribbling                                30                            80
# curve                                    14                            77
# freekick_accuracy                        11                            76
# long_passing                             59                            52
# ball_control                             46                            82
# acceleration                             54                            75
# sprint_speed                             60                            76
# agility                                  51                            77
# reactions                                84                            91
# balance                                  35                            59
# shot_power                               25                            87
# jumping                                  77                            88
# stamina                                  43                            92
# strength                                 80                            78
# long_shots                               16                            79
# aggression                               29                            84
# interceptions                            30                            48
# positioning                              12                            93
# vision                                   70                            77
# penalties                                47                            85
# composure                                70                            82
# marking                                  17                            52
# standing_tackle                          10                            45
# sliding_tackle                           11                            39
#
#                                ...                                17944  \
# name                           ...                    Cristiano Ronaldo
# full_name                      ...  Cristiano Ronaldo dos Santos Aveiro
# birth_date                     ...                             2/5/1985
# age                            ...                                   34
# height_cm                      ...                               187.96
# weight_kgs                     ...                                 83.0
# positions                      ...                                ST,LW
# nationality                    ...                             Portugal
# overall_rating                 ...                                   94
# potential                      ...                                   94
# value_euro                     ...                           77000000.0
# wage_euro                      ...                             405000.0
# preferred_foot                 ...                                Right
# international_reputation(1-5)  ...                                    5
# weak_foot(1-5)                 ...                                    4
# skill_moves(1-5)               ...                                    5
# body_type                      ...                           C. Ronaldo
# crossing                       ...                                   84
# finishing                      ...                                   94
# heading_accuracy               ...                                   89
# short_passing                  ...                                   81
# volleys                        ...                                   87
# dribbling                      ...                                   88
# curve                          ...                                   81
# freekick_accuracy              ...                                   76
# long_passing                   ...                                   77
# ball_control                   ...                                   94
# acceleration                   ...                                   89
# sprint_speed                   ...                                   91
# agility                        ...                                   87
# reactions                      ...                                   96
# balance                        ...                                   70
# shot_power                     ...                                   95
# jumping                        ...                                   95
# stamina                        ...                                   88
# strength                       ...                                   79
# long_shots                     ...                                   93
# aggression                     ...                                   63
# interceptions                  ...                                   29
# positioning                    ...                                   95
# vision                         ...                                   82
# penalties                      ...                                   85
# composure                      ...                                   95
# marking                        ...                                   28
# standing_tackle                ...                                   31
# sliding_tackle                 ...                                   23
#
#                                           17945            17946  \
# name                                   J. Serra     A. Rodriguez
# full_name                      Janni-Luca Serra  Angel Rodriguez
# birth_date                            3/13/1998        12/2/1992
# age                                          20               26
# height_cm                                193.04           175.26
# weight_kgs                                 87.1             72.1
# positions                                    ST            CM,CB
# nationality                             Germany          Uruguay
# overall_rating                               67               67
# potential                                    79               67
# value_euro                            1400000.0         825000.0
# wage_euro                                4000.0           1000.0
# preferred_foot                             Left            Right
# international_reputation(1-5)                 1                1
# weak_foot(1-5)                                4                3
# skill_moves(1-5)                              2                3
# body_type                                Normal           Normal
# crossing                                     41               58
# finishing                                    66               54
# heading_accuracy                             73               59
# short_passing                                57               73
# volleys                                      65               51
# dribbling                                    57               68
# curve                                        43               56
# freekick_accuracy                            28               49
# long_passing                                 28               72
# ball_control                                 65               65
# acceleration                                 53               66
# sprint_speed                                 65               66
# agility                                      48               57
# reactions                                    57               60
# balance                                      34               71
# shot_power                                   74               70
# jumping                                      64               62
# stamina                                      62               69
# strength                                     84               76
# long_shots                                   59               56
# aggression                                   65               72
# interceptions                                23               65
# positioning                                  69               60
# vision                                       45               60
# penalties                                    50               55
# composure                                    49               52
# marking                                      35               63
# standing_tackle                              38               64
# sliding_tackle                               33               67
#
#                                        17947                       17948  \
# name                              A. Calisir                   R. Torres
# full_name                      André Calisir  Róger Mauricio Torres Hoya
# birth_date                         6/13/1990                   7/13/1991
# age                                       28                          27
# height_cm                             154.94                      170.18
# weight_kgs                              73.9                        67.1
# positions                                 CB                         CAM
# nationality                          Armenia                    Colombia
# overall_rating                            67                          67
# potential                                 69                          68
# value_euro                          725000.0                    900000.0
# wage_euro                             2000.0                      1000.0
# preferred_foot                         Right                        Left
# international_reputation(1-5)              1                           1
# weak_foot(1-5)                             3                           3
# skill_moves(1-5)                           2                           3
# body_type                             Normal                      Normal
# crossing                                  48                          68
# finishing                                 25                          57
# heading_accuracy                          58                          52
# short_passing                             59                          64
# volleys                                   28                          57
# dribbling                                 47                          68
# curve                                     42                          70
# freekick_accuracy                         22                          68
# long_passing                              60                          61
# ball_control                              57                          65
# acceleration                              59                          81
# sprint_speed                              58                          81
# agility                                   64                          91
# reactions                                 55                          53
# balance                                   61                          89
# shot_power                                44                          70
# jumping                                   86                          71
# stamina                                   65                          65
# strength                                  72                          34
# long_shots                                27                          65
# aggression                                82                          45
# interceptions                             62                          32
# positioning                               38                          55
# vision                                    53                          72
# penalties                                 56                          64
# composure                                 64                          62
# marking                                   67                          51
# standing_tackle                           68                          38
# sliding_tackle                            68                          17
#
#                                         17949          17950        17951  \
# name                              R. McKenzie      M. Sipľak   J. Bekkema
# full_name                      Rory  McKenzie  Michal Sipľak  Jan Bekkema
# birth_date                          10/7/1993       2/2/1996     4/9/1996
# age                                        25             23           22
# height_cm                              175.26         182.88       185.42
# weight_kgs                               74.8           79.8         89.8
# positions                           RM,CAM,CM             LB           GK
# nationality                          Scotland       Slovakia  Netherlands
# overall_rating                             67             59           59
# potential                                  70             67           67
# value_euro                           975000.0       190000.0     170000.0
# wage_euro                              3000.0         1000.0       1000.0
# preferred_foot                          Right           Left        Right
# international_reputation(1-5)               1              1            1
# weak_foot(1-5)                              3              3            1
# skill_moves(1-5)                            3              2            1
# body_type                              Normal         Normal       Normal
# crossing                                   57             50           11
# finishing                                  61             19            9
# heading_accuracy                           60             53           13
# short_passing                              66             55           26
# volleys                                    37             31            9
# dribbling                                  64             52           12
# curve                                      53             26           13
# freekick_accuracy                          47             28           12
# long_passing                               61             43           24
# ball_control                               66             53           18
# acceleration                               83             70           27
# sprint_speed                               86             64           22
# agility                                    93             54           29
# reactions                                  63             50           48
# balance                                    82             53           38
# shot_power                                 51             27           17
# jumping                                    77             74           43
# stamina                                    75             66           25
# strength                                   64             70           63
# long_shots                                 54             22            9
# aggression                                 69             62           27
# interceptions                              41             55           10
# positioning                                60             42            5
# vision                                     64             39           25
# penalties                                  63             32           16
# composure                                  56             52           47
# marking                                    40             53            9
# standing_tackle                            20             64           12
# sliding_tackle                             18             60           13
#
#                                              17952  \
# name                                    A. Al Yami
# full_name                      Abdulrahman Al Yami
# birth_date                               6/19/1997
# age                                             21
# height_cm                                   175.26
# weight_kgs                                    64.9
# positions                                    ST,LM
# nationality                           Saudi Arabia
# overall_rating                                  59
# potential                                       71
# value_euro                                280000.0
# wage_euro                                   4000.0
# preferred_foot                               Right
# international_reputation(1-5)                    1
# weak_foot(1-5)                                   4
# skill_moves(1-5)                                 3
# body_type                                     Lean
# crossing                                        42
# finishing                                       60
# heading_accuracy                                55
# short_passing                                   49
# volleys                                         49
# dribbling                                       57
# curve                                           47
# freekick_accuracy                               39
# long_passing                                    37
# ball_control                                    56
# acceleration                                    84
# sprint_speed                                    86
# agility                                         65
# reactions                                       53
# balance                                         73
# shot_power                                      56
# jumping                                         58
# stamina                                         58
# strength                                        49
# long_shots                                      58
# aggression                                      38
# interceptions                                   15
# positioning                                     54
# vision                                          52
# penalties                                       50
# composure                                       53
# marking                                         16
# standing_tackle                                 18
# sliding_tackle                                  17
#
#                                                           17953
# name                                             Júnior Brumado
# full_name                      José Francisco dos Santos Júnior
# birth_date                                            5/15/1999
# age                                                          19
# height_cm                                                 190.5
# weight_kgs                                                 79.8
# positions                                                    ST
# nationality                                              Brazil
# overall_rating                                               59
# potential                                                    75
# value_euro                                             325000.0
# wage_euro                                                2000.0
# preferred_foot                                            Right
# international_reputation(1-5)                                 1
# weak_foot(1-5)                                                4
# skill_moves(1-5)                                              2
# body_type                                                Normal
# crossing                                                     32
# finishing                                                    58
# heading_accuracy                                             58
# short_passing                                                47
# volleys                                                      39
# dribbling                                                    58
# curve                                                        35
# freekick_accuracy                                            25
# long_passing                                                 37
# ball_control                                                 56
# acceleration                                                 67
# sprint_speed                                                 72
# agility                                                      71
# reactions                                                    54
# balance                                                      59
# shot_power                                                   61
# jumping                                                      60
# stamina                                                      57
# strength                                                     67
# long_shots                                                   53
# aggression                                                   67
# interceptions                                                20
# positioning                                                  53
# vision                                                       49
# penalties                                                    52
# composure                                                    45
# marking                                                      23
# standing_tackle                                              31
# sliding_tackle                                               21
#
# [46 rows x 17954 columns]

# %%
data.isna().sum()
# Out:
# name                               0
# full_name                          0
# birth_date                         0
# age                                0
# height_cm                          0
# weight_kgs                         0
# positions                          0
# nationality                        0
# overall_rating                     0
# potential                          0
# value_euro                       255
# wage_euro                        246
# preferred_foot                     0
# international_reputation(1-5)      0
# weak_foot(1-5)                     0
# skill_moves(1-5)                   0
# body_type                          0
# crossing                           0
# finishing                          0
# heading_accuracy                   0
# short_passing                      0
# volleys                            0
# dribbling                          0
# curve                              0
# freekick_accuracy                  0
# long_passing                       0
# ball_control                       0
# acceleration                       0
# sprint_speed                       0
# agility                            0
# reactions                          0
# balance                            0
# shot_power                         0
# jumping                            0
# stamina                            0
# strength                           0
# long_shots                         0
# aggression                         0
# interceptions                      0
# positioning                        0
# vision                             0
# penalties                          0
# composure                          0
# marking                            0
# standing_tackle                    0
# sliding_tackle                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17954 entries, 0 to 17953
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17954 non-null  object
#  1   full_name                      17954 non-null  object
#  2   birth_date                     17954 non-null  object
#  3   age                            17954 non-null  int64
#  4   height_cm                      17954 non-null  float64
#  5   weight_kgs                     17954 non-null  float64
#  6   positions                      17954 non-null  object
#  7   nationality                    17954 non-null  object
#  8   overall_rating                 17954 non-null  int64
#  9   potential                      17954 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17708 non-null  float64
#  12  preferred_foot                 17954 non-null  object
#  13  international_reputation(1-5)  17954 non-null  int64
#  14  weak_foot(1-5)                 17954 non-null  int64
#  15  skill_moves(1-5)               17954 non-null  int64
#  16  body_type                      17954 non-null  object
#  17  crossing                       17954 non-null  int64
#  18  finishing                      17954 non-null  int64
#  19  heading_accuracy               17954 non-null  int64
#  20  short_passing                  17954 non-null  int64
#  21  volleys                        17954 non-null  int64
#  22  dribbling                      17954 non-null  int64
#  23  curve                          17954 non-null  int64
#  24  freekick_accuracy              17954 non-null  int64
#  25  long_passing                   17954 non-null  int64
#  26  ball_control                   17954 non-null  int64
#  27  acceleration                   17954 non-null  int64
#  28  sprint_speed                   17954 non-null  int64
#  29  agility                        17954 non-null  int64
#  30  reactions                      17954 non-null  int64
#  31  balance                        17954 non-null  int64
#  32  shot_power                     17954 non-null  int64
#  33  jumping                        17954 non-null  int64
#  34  stamina                        17954 non-null  int64
#  35  strength                       17954 non-null  int64
#  36  long_shots                     17954 non-null  int64
#  37  aggression                     17954 non-null  int64
#  38  interceptions                  17954 non-null  int64
#  39  positioning                    17954 non-null  int64
#  40  vision                         17954 non-null  int64
#  41  penalties                      17954 non-null  int64
#  42  composure                      17954 non-null  int64
#  43  marking                        17954 non-null  int64
#  44  standing_tackle                17954 non-null  int64
#  45  sliding_tackle                 17954 non-null  int64
# dtypes: float64(4), int64(35), object(7)
# memory usage: 6.3+ MB

# %% [markdown]
# Removing the rows with missing values.

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17699 entries, 0 to 17953
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   name                           17699 non-null  object
#  1   full_name                      17699 non-null  object
#  2   birth_date                     17699 non-null  object
#  3   age                            17699 non-null  int64
#  4   height_cm                      17699 non-null  float64
#  5   weight_kgs                     17699 non-null  float64
#  6   positions                      17699 non-null  object
#  7   nationality                    17699 non-null  object
#  8   overall_rating                 17699 non-null  int64
#  9   potential                      17699 non-null  int64
#  10  value_euro                     17699 non-null  float64
#  11  wage_euro                      17699 non-null  float64
#  12  preferred_foot                 17699 non-null  object
#  13  international_reputation(1-5)  17699 non-null  int64
#  14  weak_foot(1-5)                 17699 non-null  int64
#  15  skill_moves(1-5)               17699 non-null  int64
#  16  body_type                      17699 non-null  object
#  17  crossing                       17699 non-null  int64
#  18  finishing                      17699 non-null  int64
#  19  heading_accuracy               17699 non-null  int64
#  20  short_passing                  17699 non-null  int64
#  21  volleys                        17699 non-null  int64
#  22  dribbling                      17699 non-null  int64
#  23  curve                          17699 non-null  int64
#  24  freekick_accuracy              17699 non-null  int64
#  25  long_passing                   17699 non-null  int64
#  26  ball_control                   17699 non-null  int64
#  27  acceleration                   17699 non-null  int64
#  28  sprint_speed                   17699 non-null  int64
#  29  agility                        17699 non-null  int64
#  30  reactions                      17699 non-null  int64
#  31  balance                        17699 non-null  int64
#  32  shot_power                     17699 non-null  int64
#  33  jumping                        17699 non-null  int64
#  34  stamina                        17699 non-null  int64
#  35  strength                       17699 non-null  int64
#  36  long_shots                     17699 non-null  int64
#  37  aggression                     17699 non-null  int64
#  38  interceptions                  17699 non-null  int64
#  39  positioning                    17699 non-null  int64
#  40  vision                         17699 non-null  int64
#  41  penalties                      17699 non-null  int64
#  42  composure                      17699 non-null  int64
#  43  marking                        17699 non-null  int64
#  44  standing_tackle                17699 non-null  int64
#  45  sliding_tackle                 17699 non-null  int64
# dtypes: float64(4), int64(35), object(7)
# memory usage: 6.3+ MB

# %% [markdown]
# Grouping features of players into 4 groups such as Player skills,Physique,Defensive skills and Offensive skills.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data['player_skills'] = data['curve'] + data['dribbling'] + data['agility'] + data['ball_control'] + data['vision'] + data['composure'] + data['reactions'] + data['balance']
data['player_skills'] = data['player_skills']/8
data['player_skills']
# Out:
# 0        94.875
# 1        86.125
# 2        82.625
# 3        88.750
# 4        57.625
#           ...
# 17949    67.625
# 17950    47.375
# 17951    28.750
# 17952    57.000
# 17953    53.375
# Name: player_skills, Length: 17699, dtype: float64

# %% [markdown]
# New column created (Player skills) with all of these skills out of 100.

# %%
data['physique'] = data['strength'] + data['stamina'] + data['sprint_speed'] + data['jumping'] + data['acceleration']
data['physique'] = data['physique']/5
data['physique']
# Out:
# 0        76.6
# 1        69.8
# 2        81.6
# 3        70.4
# 4        79.0
#          ...
# 17949    77.0
# 17950    68.8
# 17951    36.0
# 17952    67.0
# 17953    64.6
# Name: physique, Length: 17699, dtype: float64

# %% [markdown]
# Column created using all features of physique named 'Physique'.

# %%
data['offensive_skills'] = data['crossing'] + data['long_shots'] + data['volleys'] + data['finishing'] + data['heading_accuracy'] + data['short_passing'] + data['freekick_accuracy'] + data['long_passing'] + data['shot_power'] + data['aggression'] + data['positioning'] + data['penalties']
data['offensive_skills'] = data['offensive_skills']/12
data['offensive_skills']
# Out:
# 0        84.000000
# 1        78.166667
# 2        82.250000
# 3        72.500000
# 4        43.250000
#            ...
# 17949    57.166667
# 17950    38.666667
# 17951    14.833333
# 17952    48.916667
# 17953    48.500000
# Name: offensive_skills, Length: 17699, dtype: float64

# %% [markdown]
# New column with offensive skills.

# %%
data['defensive_skills'] = data['sliding_tackle'] + data['standing_tackle'] + data['marking'] + data['interceptions']
data['defensive_skills'] = data['defensive_skills']/4
data['defensive_skills']
# Out:
# 0        27.25
# 1        48.50
# 2        65.25
# 3        30.75
# 4        88.50
#          ...
# 17949    29.75
# 17950    58.00
# 17951    11.00
# 17952    16.50
# 17953    23.75
# Name: defensive_skills, Length: 17699, dtype: float64

# %% [markdown]
# New column with Defensive skills.

# %% [markdown]
# Now removing all the columns with these features.

# %%
drop_skills = ['crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
       'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
       'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
       'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
       'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
       'composure', 'marking', 'standing_tackle', 'sliding_tackle']

# %%
data.drop(drop_skills,axis=1,inplace=True)

# %%
data.T
# Out:
#                                                         0      \
# name                                                 L. Messi
# full_name                      Lionel Andrés Messi Cuccittini
# birth_date                                          6/24/1987
# age                                                        31
# height_cm                                              170.18
# weight_kgs                                               72.1
# positions                                            CF,RW,ST
# nationality                                         Argentina
# overall_rating                                             94
# potential                                                  94
# value_euro                                        110500000.0
# wage_euro                                            565000.0
# preferred_foot                                           Left
# international_reputation(1-5)                               5
# weak_foot(1-5)                                              4
# skill_moves(1-5)                                            4
# body_type                                               Messi
# player_skills                                          94.875
# physique                                                 76.6
# offensive_skills                                         84.0
# defensive_skills                                        27.25
#
#                                                       1           2      \
# name                                             C. Eriksen    P. Pogba
# full_name                      Christian  Dannemann Eriksen  Paul Pogba
# birth_date                                        2/14/1992   3/15/1993
# age                                                      27          25
# height_cm                                            154.94       190.5
# weight_kgs                                             76.2        83.9
# positions                                         CAM,RM,CM      CM,CAM
# nationality                                         Denmark      France
# overall_rating                                           88          88
# potential                                                89          91
# value_euro                                       69500000.0  73000000.0
# wage_euro                                          205000.0    255000.0
# preferred_foot                                        Right       Right
# international_reputation(1-5)                             3           4
# weak_foot(1-5)                                            5           4
# skill_moves(1-5)                                          4           5
# body_type                                              Lean      Normal
# player_skills                                        86.125      82.625
# physique                                               69.8        81.6
# offensive_skills                                  78.166667       82.25
# defensive_skills                                       48.5       65.25
#
#                                          3                  4      \
# name                                L. Insigne       K. Koulibaly
# full_name                      Lorenzo Insigne  Kalidou Koulibaly
# birth_date                            6/4/1991          6/20/1991
# age                                         27                 27
# height_cm                               162.56             187.96
# weight_kgs                                59.0               88.9
# positions                                LW,ST                 CB
# nationality                              Italy            Senegal
# overall_rating                              88                 88
# potential                                   88                 91
# value_euro                          62000000.0         60000000.0
# wage_euro                             165000.0           135000.0
# preferred_foot                           Right              Right
# international_reputation(1-5)                3                  3
# weak_foot(1-5)                               4                  3
# skill_moves(1-5)                             4                  2
# body_type                               Normal             Normal
# player_skills                            88.75             57.625
# physique                                  70.4               79.0
# offensive_skills                          72.5              43.25
# defensive_skills                         30.75               88.5
#
#                                          5              6      \
# name                               V. van Dijk      K. Mbappé
# full_name                      Virgil van Dijk  Kylian Mbappé
# birth_date                            7/8/1991     12/20/1998
# age                                         27             20
# height_cm                               193.04          152.4
# weight_kgs                                92.1           73.0
# positions                                   CB       RW,ST,RM
# nationality                        Netherlands         France
# overall_rating                              88             88
# potential                                   90             95
# value_euro                          59500000.0     81000000.0
# wage_euro                             215000.0       100000.0
# preferred_foot                           Right          Right
# international_reputation(1-5)                3              3
# weak_foot(1-5)                               3              4
# skill_moves(1-5)                             2              5
# body_type                               Normal           Lean
# player_skills                            68.75           86.0
# physique                                  81.2           84.2
# offensive_skills                     66.083333          76.25
# defensive_skills                         87.75           34.5
#
#                                                            7      \
# name                                                   S. Agüero
# full_name                      Sergio Leonel Agüero del Castillo
# birth_date                                              6/2/1988
# age                                                           30
# height_cm                                                 172.72
# weight_kgs                                                  69.9
# positions                                                     ST
# nationality                                            Argentina
# overall_rating                                                89
# potential                                                     89
# value_euro                                            64500000.0
# wage_euro                                               300000.0
# preferred_foot                                             Right
# international_reputation(1-5)                                  4
# weak_foot(1-5)                                                 4
# skill_moves(1-5)                                               4
# body_type                                                 Stocky
# player_skills                                               87.5
# physique                                                    79.6
# offensive_skills                                            79.5
# defensive_skills                                            21.5
#
#                                       8                             9      \
# name                               M. Neuer                     E. Cavani
# full_name                      Manuel Neuer  Edinson Roberto Cavani Gómez
# birth_date                        3/27/1986                     2/14/1987
# age                                      32                            32
# height_cm                            193.04                        185.42
# weight_kgs                             92.1                          77.1
# positions                                GK                            ST
# nationality                         Germany                       Uruguay
# overall_rating                           89                            89
# potential                                89                            89
# value_euro                       38000000.0                    60000000.0
# wage_euro                          130000.0                      200000.0
# preferred_foot                        Right                         Right
# international_reputation(1-5)             5                             4
# weak_foot(1-5)                            4                             4
# skill_moves(1-5)                          1                             3
# body_type                            Normal                          Lean
# player_skills                          50.0                        78.125
# physique                               62.8                          81.8
# offensive_skills                       26.5                          81.0
# defensive_skills                       17.0                          46.0
#
#                                ...                                17944  \
# name                           ...                    Cristiano Ronaldo
# full_name                      ...  Cristiano Ronaldo dos Santos Aveiro
# birth_date                     ...                             2/5/1985
# age                            ...                                   34
# height_cm                      ...                               187.96
# weight_kgs                     ...                                 83.0
# positions                      ...                                ST,LW
# nationality                    ...                             Portugal
# overall_rating                 ...                                   94
# potential                      ...                                   94
# value_euro                     ...                           77000000.0
# wage_euro                      ...                             405000.0
# preferred_foot                 ...                                Right
# international_reputation(1-5)  ...                                    5
# weak_foot(1-5)                 ...                                    4
# skill_moves(1-5)               ...                                    5
# body_type                      ...                           C. Ronaldo
# player_skills                  ...                               86.625
# physique                       ...                                 88.4
# offensive_skills               ...                            84.916667
# defensive_skills               ...                                27.75
#
#                                           17945            17946  \
# name                                   J. Serra     A. Rodriguez
# full_name                      Janni-Luca Serra  Angel Rodriguez
# birth_date                            3/13/1998        12/2/1992
# age                                          20               26
# height_cm                                193.04           175.26
# weight_kgs                                 87.1             72.1
# positions                                    ST            CM,CB
# nationality                             Germany          Uruguay
# overall_rating                               67               67
# potential                                    79               67
# value_euro                            1400000.0         825000.0
# wage_euro                                4000.0           1000.0
# preferred_foot                             Left            Right
# international_reputation(1-5)                 1                1
# weak_foot(1-5)                                4                3
# skill_moves(1-5)                              2                3
# body_type                                Normal           Normal
# player_skills                             49.75           61.125
# physique                                   65.6             67.8
# offensive_skills                          56.25            60.75
# defensive_skills                          32.25            64.75
#
#                                        17947                       17948  \
# name                              A. Calisir                   R. Torres
# full_name                      André Calisir  Róger Mauricio Torres Hoya
# birth_date                         6/13/1990                   7/13/1991
# age                                       28                          27
# height_cm                             154.94                      170.18
# weight_kgs                              73.9                        67.1
# positions                                 CB                         CAM
# nationality                          Armenia                    Colombia
# overall_rating                            67                          67
# potential                                 69                          68
# value_euro                          725000.0                    900000.0
# wage_euro                             2000.0                      1000.0
# preferred_foot                         Right                        Left
# international_reputation(1-5)              1                           1
# weak_foot(1-5)                             3                           3
# skill_moves(1-5)                           2                           3
# body_type                             Normal                      Normal
# player_skills                         55.375                       71.25
# physique                                68.0                        66.4
# offensive_skills                   45.583333                        60.5
# defensive_skills                       66.25                        34.5
#
#                                         17949          17950        17951  \
# name                              R. McKenzie      M. Sipľak   J. Bekkema
# full_name                      Rory  McKenzie  Michal Sipľak  Jan Bekkema
# birth_date                          10/7/1993       2/2/1996     4/9/1996
# age                                        25             23           22
# height_cm                              175.26         182.88       185.42
# weight_kgs                               74.8           79.8         89.8
# positions                           RM,CAM,CM             LB           GK
# nationality                          Scotland       Slovakia  Netherlands
# overall_rating                             67             59           59
# potential                                  70             67           67
# value_euro                           975000.0       190000.0     170000.0
# wage_euro                              3000.0         1000.0       1000.0
# preferred_foot                          Right           Left        Right
# international_reputation(1-5)               1              1            1
# weak_foot(1-5)                              3              3            1
# skill_moves(1-5)                            3              2            1
# body_type                              Normal         Normal       Normal
# player_skills                          67.625         47.375        28.75
# physique                                 77.0           68.8         36.0
# offensive_skills                    57.166667      38.666667    14.833333
# defensive_skills                        29.75           58.0         11.0
#
#                                              17952  \
# name                                    A. Al Yami
# full_name                      Abdulrahman Al Yami
# birth_date                               6/19/1997
# age                                             21
# height_cm                                   175.26
# weight_kgs                                    64.9
# positions                                    ST,LM
# nationality                           Saudi Arabia
# overall_rating                                  59
# potential                                       71
# value_euro                                280000.0
# wage_euro                                   4000.0
# preferred_foot                               Right
# international_reputation(1-5)                    1
# weak_foot(1-5)                                   4
# skill_moves(1-5)                                 3
# body_type                                     Lean
# player_skills                                 57.0
# physique                                      67.0
# offensive_skills                         48.916667
# defensive_skills                              16.5
#
#                                                           17953
# name                                             Júnior Brumado
# full_name                      José Francisco dos Santos Júnior
# birth_date                                            5/15/1999
# age                                                          19
# height_cm                                                 190.5
# weight_kgs                                                 79.8
# positions                                                    ST
# nationality                                              Brazil
# overall_rating                                               59
# potential                                                    75
# value_euro                                             325000.0
# wage_euro                                                2000.0
# preferred_foot                                            Right
# international_reputation(1-5)                                 1
# weak_foot(1-5)                                                4
# skill_moves(1-5)                                              2
# body_type                                                Normal
# player_skills                                            53.375
# physique                                                   64.6
# offensive_skills                                           48.5
# defensive_skills                                          23.75
#
# [21 rows x 17699 columns]

# %%
data.describe()
# Out:
#                 age     height_cm    weight_kgs  overall_rating     potential  \
# count  17699.000000  17699.000000  17699.000000    17699.000000  17699.000000
# mean      25.533533    174.930355     75.290225       66.225662     71.449686
# std        4.696970     14.036180      7.086058        6.974595      6.134616
# min       17.000000    152.400000     49.900000       47.000000     50.000000
# 25%       22.000000    154.940000     69.900000       62.000000     67.000000
# 50%       25.000000    175.260000     74.800000       66.000000     71.000000
# 75%       29.000000    185.420000     79.800000       71.000000     75.000000
# max       46.000000    205.740000    110.200000       94.000000     95.000000
#
#          value_euro      wage_euro  international_reputation(1-5)  \
# count  1.769900e+04   17699.000000                   17699.000000
# mean   2.479280e+06    9905.192384                       1.111984
# std    5.687014e+06   22000.455764                       0.393044
# min    1.000000e+04    1000.000000                       1.000000
# 25%    3.250000e+05    1000.000000                       1.000000
# 50%    7.000000e+05    3000.000000                       1.000000
# 75%    2.100000e+06    9000.000000                       1.000000
# max    1.105000e+08  565000.000000                       5.000000
#
#        weak_foot(1-5)  skill_moves(1-5)  player_skills      physique  \
# count    17699.000000      17699.000000   17699.000000  17699.000000
# mean         2.945703          2.362450      57.740501     64.566563
# std          0.663312          0.762802      12.301017      9.798357
# min          1.000000          1.000000      20.000000     23.000000
# 25%          3.000000          2.000000      51.250000     60.400000
# 50%          3.000000          2.000000      59.875000     66.400000
# 75%          3.000000          3.000000      66.375000     71.200000
# max          5.000000          5.000000      94.875000     88.400000
#
#        offensive_skills  defensive_skills
# count      17699.000000      17699.000000
# mean          50.022449         46.816459
# std           14.743959         20.340342
# min           10.250000          8.000000
# 25%           43.916667         27.500000
# 50%           52.916667         52.750000
# 75%           60.083333         64.250000
# max           84.916667         91.250000

# %%
data.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'body_type', 'player_skills',
#        'physique', 'offensive_skills', 'defensive_skills'],
#       dtype='object')

# %% [markdown]
# Creating another column named 'Player Rating' from the columns ('international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)').
# This column contains rating out of 5.

# %%
data['player_rating'] = data['international_reputation(1-5)'] + data['weak_foot(1-5)'] + data['skill_moves(1-5)']
data['player_rating'] = data['player_rating']/3
data['player_rating']
# Out:
# 0        4.333333
# 1        4.000000
# 2        4.333333
# 3        3.666667
# 4        2.666667
#            ...
# 17949    2.333333
# 17950    2.000000
# 17951    1.000000
# 17952    2.666667
# 17953    2.333333
# Name: player_rating, Length: 17699, dtype: float64

# %% [markdown]
# Dropping these three columns.

# %%
drop_rating = ['international_reputation(1-5)','weak_foot(1-5)','skill_moves(1-5)']

# %%
data.drop(drop_rating,axis=1,inplace=True)

# %%
data
# Out:
#                  name                         full_name birth_date  age  \
# 0            L. Messi    Lionel Andrés Messi Cuccittini  6/24/1987   31
# 1          C. Eriksen      Christian  Dannemann Eriksen  2/14/1992   27
# 2            P. Pogba                        Paul Pogba  3/15/1993   25
# 3          L. Insigne                   Lorenzo Insigne   6/4/1991   27
# 4        K. Koulibaly                 Kalidou Koulibaly  6/20/1991   27
# ...               ...                               ...        ...  ...
# 17949     R. McKenzie                    Rory  McKenzie  10/7/1993   25
# 17950       M. Sipľak                     Michal Sipľak   2/2/1996   23
# 17951      J. Bekkema                       Jan Bekkema   4/9/1996   22
# 17952      A. Al Yami               Abdulrahman Al Yami  6/19/1997   21
# 17953  Júnior Brumado  José Francisco dos Santos Júnior  5/15/1999   19
#
#        height_cm  weight_kgs  positions   nationality  overall_rating  \
# 0         170.18        72.1   CF,RW,ST     Argentina              94
# 1         154.94        76.2  CAM,RM,CM       Denmark              88
# 2         190.50        83.9     CM,CAM        France              88
# 3         162.56        59.0      LW,ST         Italy              88
# 4         187.96        88.9         CB       Senegal              88
# ...          ...         ...        ...           ...             ...
# 17949     175.26        74.8  RM,CAM,CM      Scotland              67
# 17950     182.88        79.8         LB      Slovakia              59
# 17951     185.42        89.8         GK   Netherlands              59
# 17952     175.26        64.9      ST,LM  Saudi Arabia              59
# 17953     190.50        79.8         ST        Brazil              59
#
#        potential   value_euro  wage_euro preferred_foot body_type  \
# 0             94  110500000.0   565000.0           Left     Messi
# 1             89   69500000.0   205000.0          Right      Lean
# 2             91   73000000.0   255000.0          Right    Normal
# 3             88   62000000.0   165000.0          Right    Normal
# 4             91   60000000.0   135000.0          Right    Normal
# ...          ...          ...        ...            ...       ...
# 17949         70     975000.0     3000.0          Right    Normal
# 17950         67     190000.0     1000.0           Left    Normal
# 17951         67     170000.0     1000.0          Right    Normal
# 17952         71     280000.0     4000.0          Right      Lean
# 17953         75     325000.0     2000.0          Right    Normal
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 0             94.875      76.6         84.000000             27.25
# 1             86.125      69.8         78.166667             48.50
# 2             82.625      81.6         82.250000             65.25
# 3             88.750      70.4         72.500000             30.75
# 4             57.625      79.0         43.250000             88.50
# ...              ...       ...               ...               ...
# 17949         67.625      77.0         57.166667             29.75
# 17950         47.375      68.8         38.666667             58.00
# 17951         28.750      36.0         14.833333             11.00
# 17952         57.000      67.0         48.916667             16.50
# 17953         53.375      64.6         48.500000             23.75
#
#        player_rating
# 0           4.333333
# 1           4.000000
# 2           4.333333
# 3           3.666667
# 4           2.666667
# ...              ...
# 17949       2.333333
# 17950       2.000000
# 17951       1.000000
# 17952       2.666667
# 17953       2.333333
#
# [17699 rows x 19 columns]

# %% [markdown]
# Dropping the columns 'full_name' & 'birth_date' because 'Name' & 'Age' columns are there.

# %%
data.drop(['full_name','birth_date','body_type'],axis=1,inplace=True)

# %%
data
# Out:
#                  name  age  height_cm  weight_kgs  positions   nationality  \
# 0            L. Messi   31     170.18        72.1   CF,RW,ST     Argentina
# 1          C. Eriksen   27     154.94        76.2  CAM,RM,CM       Denmark
# 2            P. Pogba   25     190.50        83.9     CM,CAM        France
# 3          L. Insigne   27     162.56        59.0      LW,ST         Italy
# 4        K. Koulibaly   27     187.96        88.9         CB       Senegal
# ...               ...  ...        ...         ...        ...           ...
# 17949     R. McKenzie   25     175.26        74.8  RM,CAM,CM      Scotland
# 17950       M. Sipľak   23     182.88        79.8         LB      Slovakia
# 17951      J. Bekkema   22     185.42        89.8         GK   Netherlands
# 17952      A. Al Yami   21     175.26        64.9      ST,LM  Saudi Arabia
# 17953  Júnior Brumado   19     190.50        79.8         ST        Brazil
#
#        overall_rating  potential   value_euro  wage_euro preferred_foot  \
# 0                  94         94  110500000.0   565000.0           Left
# 1                  88         89   69500000.0   205000.0          Right
# 2                  88         91   73000000.0   255000.0          Right
# 3                  88         88   62000000.0   165000.0          Right
# 4                  88         91   60000000.0   135000.0          Right
# ...               ...        ...          ...        ...            ...
# 17949              67         70     975000.0     3000.0          Right
# 17950              59         67     190000.0     1000.0           Left
# 17951              59         67     170000.0     1000.0          Right
# 17952              59         71     280000.0     4000.0          Right
# 17953              59         75     325000.0     2000.0          Right
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 0             94.875      76.6         84.000000             27.25
# 1             86.125      69.8         78.166667             48.50
# 2             82.625      81.6         82.250000             65.25
# 3             88.750      70.4         72.500000             30.75
# 4             57.625      79.0         43.250000             88.50
# ...              ...       ...               ...               ...
# 17949         67.625      77.0         57.166667             29.75
# 17950         47.375      68.8         38.666667             58.00
# 17951         28.750      36.0         14.833333             11.00
# 17952         57.000      67.0         48.916667             16.50
# 17953         53.375      64.6         48.500000             23.75
#
#        player_rating
# 0           4.333333
# 1           4.000000
# 2           4.333333
# 3           3.666667
# 4           2.666667
# ...              ...
# 17949       2.333333
# 17950       2.000000
# 17951       1.000000
# 17952       2.666667
# 17953       2.333333
#
# [17699 rows x 16 columns]

# %%
data['positions'].unique()
# Out:
# array(['CF,RW,ST', 'CAM,RM,CM', 'CM,CAM', 'LW,ST', 'CB', 'RW,ST,RM', 'ST',
#        'GK', 'CDM,CM', 'CF,ST', 'RW,ST', 'CAM,RW', 'CDM', 'CM,CDM', 'LB',
#        'CM,CAM,CDM', 'CAM,CM,LW', 'CAM,CM,RM', 'LW,ST,LM', 'CAM,CM',
#        'CAM', 'LW,RW', 'RW,LW', 'CM,LM', 'CM', 'RM,RW', 'LM,RM,CAM,LW',
#        'LM', 'RW,RM', 'LM,ST,RM', 'RB', 'LM,RM,LW,RW', 'LM,CAM,RM',
#        'RM,LM,ST', 'RW', 'LM,ST,RM,LW', 'CM,CDM,CAM', 'CM,CDM,CB',
#        'CB,CDM', 'CF,ST,CAM', 'CDM,CB', 'RB,RWB', 'RM', 'LM,CAM', 'CM,LW',
#        'LB,LWB,LM', 'ST,LW', 'LM,LB,CM', 'RB,RM', 'RM,LM,CM', 'LM,RM,CAM',
#        'RM,RW,ST', 'LW,LM,RW', 'LB,LM', 'ST,LW,LM', 'RM,CM', 'CM,RM',
#        'CB,RB', 'RM,RW,LM', 'LM,RM', 'CDM,CB,CM', 'CAM,CDM', 'LB,CDM',
#        'CAM,RM,LM', 'RM,CAM,CM', 'LWB', 'CDM,CM,LM', 'CDM,CM,RM',
#        'CDM,CM,CB', 'CAM,LW', 'RM,LM', 'ST,CAM', 'LM,CM', 'ST,CF,CAM,LM',
#        'LWB,LB,CB,LM', 'RB,LB', 'LW', 'CAM,ST', 'LM,RM,LW', 'LWB,LM,LB',
#        'ST,CF,LM,CAM', 'LM,LW,ST', 'LB,LWB', 'RWB,RB,RM', 'ST,RW',
#        'CAM,CM,LM', 'RB,RW', 'RM,CAM,LM', 'ST,RM', 'RM,ST', 'CM,LM,RM',
#        'CM,CAM,LM', 'RW,RWB', 'LM,RB', 'RM,LM,RW,CAM', 'ST,RM,RWB,LM',
#        'LB,RB', 'CM,CDM,RM', 'LM,LW', 'CAM,ST,RM', 'ST,CF', 'CB,LB',
#        'RWB,RM', 'LM,CM,LW', 'CF,LW', 'CAM,CM,RW', 'CAM,LM,RW',
#        'ST,RW,LW,CF', 'CM,RM,RB', 'RM,CM,LM', 'LW,RM', 'CB,RB,LB',
#        'CAM,CF,ST', 'CAM,CF', 'CAM,CM,ST', 'RB,CB', 'ST,LM,RM',
#        'CM,RM,LM', 'LWB,LB,LM,CDM', 'RM,RW,CM,CAM', 'LB,RB,RWB',
#        'RB,RWB,RM', 'CAM,RM', 'LWB,LB,LM', 'CM,LM,CAM', 'CAM,LM,RM,RW',
#        'ST,LM', 'RM,CAM', 'CAM,LM,RM', 'LW,RW,CAM', 'CF,ST,LW', 'LM,RW',
#        'RW,LW,LM', 'RWB,LB', 'LM,ST', 'RB,RM,LB,LM', 'LWB,LM', 'LW,CF',
#        'CAM,CDM,RM', 'LWB,LB,RB,RWB', 'CM,RW,CAM', 'RB,CM',
#        'CM,CDM,CAM,RM', 'RM,RB', 'CM,LM,CDM', 'LM,CM,CAM', 'LM,RM,CM',
#        'RM,LM,RW', 'LM,RM,RW', 'RW,LW,ST', 'LW,RW,RM', 'CDM,RB',
#        'RW,RM,CAM', 'CB,LB,RB', 'CM,CAM,ST', 'CF,CAM,ST', 'RW,CAM,RM',
#        'CDM,LB,CM', 'CAM,LM,CM', 'LB,LWB,CDM', 'RM,RB,RW', 'RM,CAM,LM,CM',
#        'RB,RWB,LB', 'CAM,CM,CDM', 'LM,RM,ST,LB', 'CDM,CM,CAM', 'CF,CAM',
#        'RM,LM,CAM', 'RW,LW,RM', 'LW,CAM', 'RB,CB,RWB,RM', 'ST,LW,RW',
#        'CAM,RW,ST', 'ST,CAM,RW,LW', 'LB,CB,LM', 'CM,LM,LB', 'RB,LB,RWB',
#        'ST,RM,LM', 'LB,CB', 'ST,CAM,CF', 'CDM,CAM,CM,LM', 'CAM,LM',
#        'LB,CM,LWB', 'RW,CAM', 'LM,CM,RM,CAM', 'CAM,RW,LW', 'RM,LM,RW,RWB',
#        'CDM,RB,RM', 'LW,LM,RM,RW', 'ST,RW,LW', 'RB,CB,CDM', 'LM,CF,CAM',
#        'ST,RW,CF', 'CM,RB', 'CF,ST,CAM,LM', 'RM,LM,CM,CDM',
#        'ST,RM,LM,CAM', 'LM,LW,CAM', 'CAM,LB,CM', 'RM,RW,ST,CAM', 'LM,LB',
#        'LW,CM,CAM', 'LW,LM', 'RM,LM,CAM,ST', 'LW,ST,RW', 'LM,LWB,LB,LW',
#        'LW,LM,CF', 'CAM,CM,RWB', 'CAM,CF,CM,RM', 'LM,CAM,LW', 'LM,RM,ST',
#        'RB,CDM,CM', 'CM,CDM,LM', 'LW,LM,RW,CAM', 'LM,LW,RM', 'RM,LW,CAM',
#        'CM,LB', 'CM,CDM,LW', 'CM,CAM,LM,CDM', 'ST,LM,CAM', 'CF,LM,ST,CAM',
#        'RB,CB,RM', 'CAM,RB', 'RB,CB,RWB', 'LB,LW', 'CDM,RM,RB',
#        'RB,CB,LB', 'LM,CAM,RM,CF', 'ST,RM,CAM,LM', 'LM,RM,CM,CAM',
#        'RB,RM,RWB', 'LB,CB,LWB', 'CB,RB,CDM', 'RM,ST,RW', 'CM,CF',
#        'CB,CDM,CM', 'CDM,CAM', 'LM,LW,RW', 'LM,CF', 'LM,LW,RM,ST',
#        'LB,LM,LWB', 'ST,LM,RW,RM', 'RW,RM,CM', 'RM,RW,LW', 'CAM,RM,LM,CM',
#        'CAM,CM,RM,LM', 'RB,LB,CDM,CM', 'RB,LB,CB', 'CM,RM,CDM',
#        'LW,RW,LM', 'ST,CF,CAM', 'CM,LB,CDM', 'RW,CM', 'CDM,CAM,CM',
#        'LM,RM,CF', 'LW,CAM,ST', 'RB,LB,RM', 'RB,LB,CDM', 'CDM,CM,CB,LM',
#        'ST,RM,CAM', 'CM,RM,CAM', 'CB,LB,CDM', 'RB,CM,RM', 'LB,CB,CDM',
#        'RM,RWB', 'CAM,LB,CM,RM', 'CB,CM', 'RM,CM,RB', 'CAM,LM,ST',
#        'LB,LWB,CB,LM', 'RM,CAM,ST', 'LB,RB,RM', 'RWB,RB,LWB',
#        'RM,RWB,LM,CAM', 'RWB,CB', 'LM,CM,ST', 'CM,CB,CDM', 'RW,LW,CM',
#        'CDM,CM,CAM,RM', 'RW,RM,LW,ST', 'LB,RB,LM', 'RB,CDM', 'RM,ST,LM',
#        'ST,RW,CAM', 'LM,ST,CAM', 'RW,CAM,LW', 'RB,LM', 'RB,RW,LW',
#        'CM,RW', 'LB,LW,RW', 'CDM,RB,CM', 'RB,RM,LB', 'LM,CAM,CM',
#        'RM,RW,LM,LW', 'LM,LWB,CM', 'RW,RM,LM,ST', 'CAM,LW,RB',
#        'CM,LW,RW,LM', 'ST,CF,RW', 'ST,RW,CF,RM', 'RB,CM,CDM', 'LM,ST,LW',
#        'LB,LM,RM', 'CAM,CM,RM,ST', 'RW,LB', 'LWB,LB', 'CAM,RM,RW',
#        'CDM,LWB', 'CM,CAM,CF', 'CAM,ST,LM', 'CM,CDM,CAM,ST',
#        'CDM,LM,CAM,CM', 'ST,CAM,LM', 'CF,ST,CAM,LW', 'RM,LM,RW,LW',
#        'CB,RB,LB,CDM', 'RB,RM,LM', 'ST,LW,CAM', 'CDM,RM,CAM', 'CB,CDM,RB',
#        'LM,LWB', 'RB,LB,LWB', 'CAM,CM,LM,RM', 'LM,CAM,RW,CF', 'CAM,ST,CM',
#        'LM,CM,RM', 'LM,ST,CM', 'RM,RB,CB', 'LB,CDM,CM', 'LB,RB,CB',
#        'LW,RW,CM,RB', 'RW,RM,CAM,ST', 'RM,RWB,ST', 'LM,CAM,RM,CDM',
#        'CM,CDM,CAM,LM', 'CB,RB,CM', 'CAM,CDM,CM', 'RM,CAM,CM,LM',
#        'LB,LM,LW', 'ST,CF,RM', 'RB,LM,RM', 'RW,LM,CAM', 'LB,CB,LM,CM',
#        'RB,RM,CB', 'CF,RW,CM', 'LB,LM,RB', 'RWB,RB', 'ST,LM,LW', 'LB,CM',
#        'LB,LM,ST', 'CM,CDM,RB,RWB', 'LB,RWB,LWB', 'RM,RB,LB', 'LW,RW,ST',
#        'RB,CDM,CB,LB', 'LM,RM,CM,CDM', 'LM,CAM,CDM', 'RM,LM,CF,CAM',
#        'CDM,RM,CM', 'CB,LWB,LM', 'RM,ST,LM,RW', 'RM,LM,RB,CF', 'CF,LM',
#        'RM,RB,RWB', 'RB,LB,LWB,RWB', 'RM,RWB,RB', 'CM,LW,LWB', 'LW,RB,LB',
#        'LB,RM', 'LW,LM,ST,RM', 'RM,ST,CAM', 'CM,ST', 'LM,RW,LW',
#        'CAM,CM,CF', 'CM,LM,LW,CAM', 'LW,CAM,RW', 'ST,CF,LW',
#        'RM,CM,ST,LM', 'ST,RW,RM', 'LW,LWB,LB,RW', 'RWB,RM,RB,LB',
#        'RW,CAM,ST', 'RWB,RB,RM,CM', 'ST,RM,RW', 'RM,LW,CAM,ST',
#        'CM,CAM,CDM,RM', 'CDM,CM,RB,CB', 'RB,CDM,LB', 'RWB,RB,RW', 'RWB',
#        'CM,CDM,LB', 'ST,CM', 'RB,LB,CM', 'RM,LM,RB', 'CM,CAM,LW',
#        'CF,ST,RM,CAM', 'RM,RB,LM', 'RM,LW', 'CF', 'RB,RW,CAM,LW',
#        'LWB,LM,LB,RWB', 'RWB,RM,RB', 'CM,CAM,RM', 'LWB,RWB', 'CM,ST,RM',
#        'CAM,CF,CM', 'RW,RM,LM', 'LW,RM,RW', 'RW,CM,CAM,LW',
#        'LM,RM,CAM,ST', 'CM,RM,LM,CAM', 'CDM,LB', 'RB,LW', 'RW,RB',
#        'ST,LW,RW,LM', 'CDM,CM,RB', 'CAM,LB', 'CM,ST,RW', 'LB,LM,CM',
#        'CM,CDM,RB', 'CF,ST,RW', 'RB,RM,LB,RWB', 'LW,CM', 'RWB,LWB',
#        'CAM,LM,RM,ST', 'RM,LM,CF', 'LB,CB,RB', 'CB,LB,LM', 'RM,RW,CAM',
#        'LB,RW,LW', 'RB,LM,LB,RM', 'LM,CAM,LB,LW', 'RB,LB,RWB,LWB',
#        'LW,RW,LB,CM', 'CM,LM,CB', 'LM,RM,LB', 'LB,RB,CDM', 'CB,RB,RWB',
#        'CDM,LM', 'LM,LW,CM', 'RM,CF', 'CB,CDM,CM,CAM', 'LM,CM,CDM,LB',
#        'LWB,LW', 'LM,RM,RB', 'RWB,RB,CDM', 'RM,LM,LWB', 'LB,CAM,LM',
#        'LW,LM,RM', 'LB,CDM,CB', 'LB,RB,LM,RM', 'LB,CB,CM', 'CB,LB,CM',
#        'LW,LB', 'ST,CAM,RW', 'CDM,CB,RB', 'CM,CF,RB', 'CM,CDM,CB,RB',
#        'CM,RWB,CDM', 'RB,RM,CDM', 'CAM,LM,LB', 'CM,CB', 'RB,RW,RM',
#        'LM,LB,CB', 'CAM,RW,CM', 'LB,LWB,CAM,LM', 'ST,LW,CDM', 'ST,RW,LM',
#        'CB,LWB', 'RM,RB,CAM,CM', 'RM,CF,LM', 'RW,LW,CAM', 'ST,LM,LWB',
#        'CAM,RW,RWB', 'LB,LW,ST', 'RB,RWB,CB', 'CM,CAM,RW', 'CB,CDM,LB',
#        'RM,LM,ST,CAM', 'ST,RM,LW', 'RM,RB,CDM', 'CM,RB,RM', 'LM,CAM,LB',
#        'CDM,RM', 'LB,LWB,CB', 'RB,RWB,CDM', 'CF,RM,CM', 'LM,CM,LB',
#        'CM,RWB,RM', 'LWB,LB,CB', 'RB,CB,LB,CDM', 'CF,RM,LM',
#        'RM,CAM,CF,LB', 'RM,RW,RWB', 'CDM,CM,RB,LM', 'LM,RM,LB,RB',
#        'RW,ST,CM', 'RB,RWB,RM,RW', 'CDM,CM,LB', 'CAM,LW,RW', 'LB,RB,LW',
#        'CAM,RW,LW,CF', 'CAM,RM,RWB', 'CAM,ST,CF', 'RW,LW,CAM,CM',
#        'LM,LB,LW', 'CAM,LM,LW', 'CM,CDM,RWB', 'CB,CM,CDM', 'ST,CB',
#        'LM,RM,LWB,CM', 'LM,LB,ST', 'LW,CM,RW', 'LW,CAM,CM,RB', 'RB,CAM',
#        'LM,LW,CF', 'CF,RW', 'CM,RWB', 'RB,ST', 'CB,ST', 'CF,CM,ST',
#        'LB,LM,CB', 'CDM,CM,CF', 'ST,LM,LW,RW', 'CM,LB,RM', 'LM,CM,RM,RB',
#        'RM,RW,RB,RWB', 'RW,LM', 'RW,RM,CF', 'CM,RM,LW', 'CAM,LW,CF',
#        'ST,LM,RM,CF', 'CAM,RM,CM,ST', 'LB,LM,LWB,CB', 'RM,CB,RB,RWB',
#        'LM,LWB,RM,RWB', 'CM,CAM,RM,CF', 'CM,LM,LB,CF', 'RM,LM,LB',
#        'LM,ST,LB', 'RM,CAM,CF', 'CB,RWB,RB', 'RW,LW,RM,ST', 'LW,RW,CM',
#        'RM,CAM,LM,CDM', 'LW,RB', 'LB,LWB,CM', 'CDM,RB,CB', 'LM,CDM,LB',
#        'LB,LW,LWB', 'LB,RB,CM', 'RB,RM,RW', 'CF,CAM,RM', 'RB,CDM,CM,RM',
#        'RWB,LM,LWB,RB', 'CAM,RW,RM', 'RM,RB,CM', 'CB,LB,LWB',
#        'CDM,LB,LM,CB', 'ST,CAM,RM', 'LWB,CB', 'CB,CM,RWB', 'LM,LB,CDM,CM',
#        'CB,RWB', 'CM,ST,LM', 'RWB,LW,RW', 'CM,CB,CAM', 'CDM,RB,LB',
#        'LB,LM,CAM', 'RM,LM,CAM,CM', 'LM,RM,LWB', 'ST,LM,CF', 'CDM,CB,LB',
#        'LB,CM,RB', 'RW,ST,LW,CF', 'CDM,CM,CB,ST', 'LM,LW,RM,RW',
#        'RW,CM,CAM', 'LM,ST,RM,CAM', 'RW,ST,LW', 'LWB,LB,CDM',
#        'ST,CAM,LM,CM', 'CAM,LM,LWB,LB', 'CB,ST,CM', 'RM,RB,ST',
#        'RWB,LM,ST', 'CM,LWB,LB', 'RB,ST,RM', 'CAM,RM,ST', 'LM,CDM',
#        'CM,CDM,LM,LB', 'CM,CB,LB', 'RB,CDM,RM', 'RW,RM,LW,LM', 'RM,LM,LW',
#        'CDM,RM,CM,CAM', 'CB,RM', 'LM,LB,LWB', 'LM,LW,CDM,LWB', 'RM,CB,RB',
#        'LW,RW,CF,ST', 'ST,LM,RW', 'LB,CM,LM', 'CAM,RM,CDM', 'RM,RW,CF',
#        'CF,RM', 'CM,CDM,CAM,CF', 'LB,RB,RM,CDM', 'CF,ST,CM',
#        'RM,LM,RB,CM', 'LM,RM,ST,CAM', 'ST,RM,RW,LM', 'CAM,CF,LM',
#        'RB,CDM,RWB', 'LM,ST,CF', 'CF,RM,CAM', 'LW,LM,CAM', 'RM,ST,LM,LW',
#        'ST,RM,LM,LW', 'CM,LW,LM,CAM', 'ST,RM,RW,LW', 'RB,CDM,CB',
#        'LW,LM,RW,RM', 'CB,LM,LB,LWB', 'RM,RWB,LM', 'ST,RB',
#        'CM,LM,RM,CAM', 'RB,CB,CM,CDM', 'RM,LW,LM', 'CB,RB,RM', 'RW,CF',
#        'CF,CAM,LW', 'RW,ST,CAM,RM', 'RM,CM,CDM', 'LM,LB,RM',
#        'LW,LM,ST,LWB', 'CAM,CF,RM', 'CAM,RM,ST,LM', 'CM,LB,LM',
#        'LM,CM,CDM,RM', 'RW,RM,LB,CM', 'CM,RW,RM', 'LB,CB,CDM,RB',
#        'CM,RM,CDM,LM', 'CM,RW,LM', 'CM,RB,CDM,LB', 'CM,LWB', 'RWB,RM,LM',
#        'CAM,RM,CM,LM', 'RB,CDM,CB,CM', 'ST,LW,CM', 'RB,CDM,RM,LB',
#        'RW,RM,CM,CAM', 'LM,RM,RW,CM', 'CDM,RM,LM', 'LW,RW,CF',
#        'CAM,RM,RB', 'CF,ST,RW,CAM', 'LM,RM,ST,CF', 'LW,RW,CAM,ST',
#        'RW,CF,LW', 'CF,CM', 'CDM,RM,LM,RB', 'CM,RW,LW', 'RM,CM,RB,RWB',
#        'CF,CM,LW', 'LB,CB,CDM,LM', 'RM,LW,RW', 'CAM,ST,CF,LM',
#        'CDM,LB,CM,RB', 'RB,RM,ST', 'LB,RB,RM,LM', 'RM,LM,RB,LB',
#        'CDM,CM,LM,CAM', 'CDM,CM,RM,RB', 'CM,CAM,RM,CDM', 'LM,LW,RW,ST',
#        'LB,LM,LWB,RM', 'CAM,LM,CDM', 'CAM,ST,RM,LM', 'LM,CAM,ST',
#        'LB,LM,RB,CM', 'CAM,CDM,CM,RM', 'CAM,RM,LM,ST', 'LM,CM,RM,CDM',
#        'LW,CAM,LM', 'CF,CAM,LM', 'LWB,RWB,LM,RM', 'LM,LW,RW,RM',
#        'RM,CAM,LM,ST', 'RM,CF,CAM', 'LW,LM,RM,CAM', 'LM,LWB,LB',
#        'CM,RM,CDM,RB', 'CB,CDM,CAM', 'LW,RM,ST,LM', 'ST,LM,RM,CM',
#        'CM,RB,CDM', 'LB,CB,LM,LWB', 'RM,CM,LM,CAM', 'RW,RM,ST',
#        'CB,LM,LB', 'LW,RW,CAM,LM', 'CM,CDM,RM,LM', 'RM,ST,LM,CAM',
#        'ST,RM,LM,CF', 'RB,RM,LM,CM', 'CAM,LW,ST', 'CAM,CM,LM,ST',
#        'LM,LWB,LW', 'CM,RM,LM,CDM', 'CM,RB,LB', 'RM,LM,LW,RW',
#        'LW,CAM,RW,RM', 'LM,RM,CAM,CM', 'LM,RM,LW,CM', 'CB,CM,CDM,CAM',
#        'LB,LM,CDM', 'RB,CB,LB,RWB', 'LWB,LB,RB', 'LM,LB,RB', 'LW,LM,ST',
#        'RB,RWB,LWB,LB', 'CAM,LW,CM', 'LWB,LM,CB,RWB', 'LM,CM,RM,ST',
#        'ST,CF,LM,RW', 'RW,CAM,CF', 'RM,RW,CAM,ST', 'RWB,RB,CDM,RM',
#        'LW,LM,CAM,ST', 'CM,RB,CAM', 'CM,ST,CAM', 'LW,RW,ST,RM',
#        'LM,RM,CM,ST', 'CF,LW,RW', 'CM,RM,LB', 'LW,LM,CAM,CF', 'CB,RB,CAM',
#        'LM,ST,CAM,LW', 'LM,CAM,CM,CF', 'RB,RW,LB', 'RM,LM,RW,LWB',
#        'RM,RW,RB,LM', 'CDM,RB,CB,CM', 'LM,ST,RW', 'RM,LM,RW,ST',
#        'LM,LW,RM,RB', 'CAM,RW,CF,RM', 'LB,CM,LW', 'ST,LW,LM,CF',
#        'RM,LM,CDM,CM', 'LW,CAM,RW,LM', 'LM,RM,LW,ST', 'RW,CAM,CM',
#        'ST,CAM,LW,RW', 'LW,LB,CM,LM', 'LM,LB,CAM', 'CAM,LW,LM,ST',
#        'CB,LWB,LB', 'CB,CM,CAM', 'RM,RW,ST,LM', 'LW,CF,RM,RW', 'RW,CM,RM',
#        'CAM,CM,CF,RM', 'CM,CF,LW', 'CDM,CM,CB,RM', 'CF,ST,LM,CAM',
#        'CM,RM,LB,RB', 'RM,CM,RW,CAM', 'RM,RB,CDM,CM', 'CAM,LM,ST,CM',
#        'CAM,LM,CM,CF', 'RM,CM,CAM,RB', 'LB,RB,LM,CM', 'RW,RM,ST,LW',
#        'RM,CM,LM,LB', 'RW,LM,RM,ST', 'RM,LM,CAM,RW', 'LB,LWB,LM,CB',
#        'CAM,RM,CF', 'CAM,CM,RM,CF', 'CM,RM,RWB', 'LM,ST,RB',
#        'ST,CAM,RM,LM', 'RM,LM,RWB,RB', 'RW,CAM,RM,CF', 'CM,LM,RB,RM',
#        'LB,RM,LM', 'RM,LM,RWB', 'CAM,RW,CF', 'RM,CM,CDM,RWB',
#        'CAM,CDM,RM,CM', 'RW,LM,RM', 'CAM,LW,LM,CM', 'RW,CAM,ST,LW',
#        'LM,CDM,CM,RM', 'RB,LB,ST', 'LM,LB,CDM', 'CDM,RWB', 'CAM,ST,LW',
#        'CAM,CF,RW', 'RM,CAM,RW', 'ST,RWB,RM', 'LM,CM,LWB', 'CF,ST,LM',
#        'CM,RB,CB', 'CAM,LM,ST,RM', 'ST,RW,LM,LW', 'RB,LB,LM',
#        'RM,RB,LM,LB', 'LM,RM,RWB', 'CF,CAM,ST,LW', 'CM,LM,CDM,CAM',
#        'ST,CAM,LM,CF', 'CAM,CM,LM,CDM', 'LM,LW,LB', 'CAM,LM,CM,ST',
#        'RM,CM,RW', 'CAM,LM,RM,CM', 'RW,RM,CF,CAM', 'CM,RM,CDM,CAM',
#        'RM,RW,CM', 'CAM,CM,CDM,RM', 'CAM,ST,LM,RM', 'CF,CAM,CM,ST',
#        'CAM,LM,LW,CM', 'LM,RM,ST,LW', 'LW,CAM,LM,CM', 'ST,CM,RB',
#        'RB,LW,LB,RW', 'CM,CDM,LWB', 'ST,LW,RW,CAM', 'RB,RM,CAM,LM',
#        'RB,CB,CM', 'RW,ST,CAM', 'CM,CAM,LM,RM', 'CDM,CAM,LM,LB',
#        'CDM,LWB,LB', 'LWB,CM,LM', 'LW,LB,LM', 'RM,CF,LM,CAM',
#        'RWB,LWB,LB,RB', 'CAM,CM,CF,CDM', 'CM,LW,RW', 'LW,RM,LM,RW',
#        'LW,LM,CM', 'LM,CAM,CF,RM', 'LWB,LM,LB,CM', 'CM,CAM,RM,LM',
#        'LW,ST,LM,CAM', 'RM,RWB,RW,CM', 'CAM,ST,CF,CM', 'CAM,ST,CDM',
#        'RM,CM,LM,RB', 'RB,LB,LM,RM', 'ST,LW,RM', 'CAM,LM,RM,CF',
#        'RB,RWB,RM,LWB', 'CDM,CM,RB,RM', 'RM,LWB', 'CM,RM,CF', 'RB,RW,CM',
#        'RWB,RM,RB,LWB', 'CF,RW,RM,LW', 'RW,ST,RM,LW', 'LW,CF,ST',
#        'LB,LW,CM', 'CM,LM,CAM,CDM', 'CM,CAM,CDM,LM', 'RW,LW,CAM,ST',
#        'CM,ST,CAM,CF', 'CAM,LW,CM,RM', 'CF,ST,LM,RM', 'CF,CAM,CM',
#        'CF,LM,RM', 'CAM,CM,RW,LW', 'CAM,CM,RM,RW', 'RB,RM,CM', 'RW,LW,CF',
#        'CF,LW,ST', 'CF,LW,CAM', 'CAM,RM,RW,CF', 'CAM,CM,RW,RM'],
#       dtype=object)

# %% [markdown]
# There are many unique values in column 'Positions' so group them as 'Forward','Midfielder','Defender' and 'Goal keeper'.

# %%
def positions_group(position):
    if 'CF' in position or 'ST' in position or 'RW' in position or 'LW' in position or 'LF' in position or 'RF' in position:
        return 'Forward'
    elif 'CAM' in position or 'RM' in position or 'CM' in position or 'LM' in position or 'DMF' in position or 'AMF' in position or 'CDM' in position:
        return 'Midfielder'
    elif 'CB' in position or 'RB' in position or 'LB' in position or 'LWB' in position or 'RWB' in position:
        return 'Defender'
    elif 'GK' in position:
        return 'GoalKeeper'
    else:
        return 'Unknown'

# %%
data['positions'] = data['positions'].map(positions_group)

# %%
data
# Out:
#                  name  age  height_cm  weight_kgs   positions   nationality  \
# 0            L. Messi   31     170.18        72.1     Forward     Argentina
# 1          C. Eriksen   27     154.94        76.2  Midfielder       Denmark
# 2            P. Pogba   25     190.50        83.9  Midfielder        France
# 3          L. Insigne   27     162.56        59.0     Forward         Italy
# 4        K. Koulibaly   27     187.96        88.9    Defender       Senegal
# ...               ...  ...        ...         ...         ...           ...
# 17949     R. McKenzie   25     175.26        74.8  Midfielder      Scotland
# 17950       M. Sipľak   23     182.88        79.8    Defender      Slovakia
# 17951      J. Bekkema   22     185.42        89.8  GoalKeeper   Netherlands
# 17952      A. Al Yami   21     175.26        64.9     Forward  Saudi Arabia
# 17953  Júnior Brumado   19     190.50        79.8     Forward        Brazil
#
#        overall_rating  potential   value_euro  wage_euro preferred_foot  \
# 0                  94         94  110500000.0   565000.0           Left
# 1                  88         89   69500000.0   205000.0          Right
# 2                  88         91   73000000.0   255000.0          Right
# 3                  88         88   62000000.0   165000.0          Right
# 4                  88         91   60000000.0   135000.0          Right
# ...               ...        ...          ...        ...            ...
# 17949              67         70     975000.0     3000.0          Right
# 17950              59         67     190000.0     1000.0           Left
# 17951              59         67     170000.0     1000.0          Right
# 17952              59         71     280000.0     4000.0          Right
# 17953              59         75     325000.0     2000.0          Right
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 0             94.875      76.6         84.000000             27.25
# 1             86.125      69.8         78.166667             48.50
# 2             82.625      81.6         82.250000             65.25
# 3             88.750      70.4         72.500000             30.75
# 4             57.625      79.0         43.250000             88.50
# ...              ...       ...               ...               ...
# 17949         67.625      77.0         57.166667             29.75
# 17950         47.375      68.8         38.666667             58.00
# 17951         28.750      36.0         14.833333             11.00
# 17952         57.000      67.0         48.916667             16.50
# 17953         53.375      64.6         48.500000             23.75
#
#        player_rating
# 0           4.333333
# 1           4.000000
# 2           4.333333
# 3           3.666667
# 4           2.666667
# ...              ...
# 17949       2.333333
# 17950       2.000000
# 17951       1.000000
# 17952       2.666667
# 17953       2.333333
#
# [17699 rows x 16 columns]

# %%
data['positions'].unique()
# Out:
# array(['Forward', 'Midfielder', 'Defender', 'GoalKeeper'], dtype=object)

# %%
data['preferred_foot'].unique()
# Out:
# array(['Left', 'Right'], dtype=object)

# %%
data.isna().sum()
# Out:
# name                0
# age                 0
# height_cm           0
# weight_kgs          0
# positions           0
# nationality         0
# overall_rating      0
# potential           0
# value_euro          0
# wage_euro           0
# preferred_foot      0
# player_skills       0
# physique            0
# offensive_skills    0
# defensive_skills    0
# player_rating       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17699 entries, 0 to 17953
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              17699 non-null  object
#  1   age               17699 non-null  int64
#  2   height_cm         17699 non-null  float64
#  3   weight_kgs        17699 non-null  float64
#  4   positions         17699 non-null  object
#  5   nationality       17699 non-null  object
#  6   overall_rating    17699 non-null  int64
#  7   potential         17699 non-null  int64
#  8   value_euro        17699 non-null  float64
#  9   wage_euro         17699 non-null  float64
#  10  preferred_foot    17699 non-null  object
#  11  player_skills     17699 non-null  float64
#  12  physique          17699 non-null  float64
#  13  offensive_skills  17699 non-null  float64
#  14  defensive_skills  17699 non-null  float64
#  15  player_rating     17699 non-null  float64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 2.8+ MB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
data['age'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.scatter(data['potential'],data['overall_rating'],color='red',alpha=0.5)
plt.title('Potential vs Overall Rating')
plt.xlabel('Potential')
plt.ylabel('Overall Rating')
# Out:
# Text(0, 0.5, 'Overall Rating')

# %% [markdown]
# Creating dummies of Categorical to encode.

# %%
data['positions'] = data['positions'].replace({'Forward':1,'Midfielder':2,'Defender':3,'GoalKeeper':4})
data['preferred_foot'] = data['preferred_foot'].replace({'Left':1,'Right':1})

# %%
data
# Out:
#                  name  age  height_cm  weight_kgs  positions   nationality  \
# 0            L. Messi   31     170.18        72.1          1     Argentina
# 1          C. Eriksen   27     154.94        76.2          2       Denmark
# 2            P. Pogba   25     190.50        83.9          2        France
# 3          L. Insigne   27     162.56        59.0          1         Italy
# 4        K. Koulibaly   27     187.96        88.9          3       Senegal
# ...               ...  ...        ...         ...        ...           ...
# 17949     R. McKenzie   25     175.26        74.8          2      Scotland
# 17950       M. Sipľak   23     182.88        79.8          3      Slovakia
# 17951      J. Bekkema   22     185.42        89.8          4   Netherlands
# 17952      A. Al Yami   21     175.26        64.9          1  Saudi Arabia
# 17953  Júnior Brumado   19     190.50        79.8          1        Brazil
#
#        overall_rating  potential   value_euro  wage_euro  preferred_foot  \
# 0                  94         94  110500000.0   565000.0               1
# 1                  88         89   69500000.0   205000.0               1
# 2                  88         91   73000000.0   255000.0               1
# 3                  88         88   62000000.0   165000.0               1
# 4                  88         91   60000000.0   135000.0               1
# ...               ...        ...          ...        ...             ...
# 17949              67         70     975000.0     3000.0               1
# 17950              59         67     190000.0     1000.0               1
# 17951              59         67     170000.0     1000.0               1
# 17952              59         71     280000.0     4000.0               1
# 17953              59         75     325000.0     2000.0               1
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 0             94.875      76.6         84.000000             27.25
# 1             86.125      69.8         78.166667             48.50
# 2             82.625      81.6         82.250000             65.25
# 3             88.750      70.4         72.500000             30.75
# 4             57.625      79.0         43.250000             88.50
# ...              ...       ...               ...               ...
# 17949         67.625      77.0         57.166667             29.75
# 17950         47.375      68.8         38.666667             58.00
# 17951         28.750      36.0         14.833333             11.00
# 17952         57.000      67.0         48.916667             16.50
# 17953         53.375      64.6         48.500000             23.75
#
#        player_rating
# 0           4.333333
# 1           4.000000
# 2           4.333333
# 3           3.666667
# 4           2.666667
# ...              ...
# 17949       2.333333
# 17950       2.000000
# 17951       1.000000
# 17952       2.666667
# 17953       2.333333
#
# [17699 rows x 16 columns]

# %%
data
# Out:
#                  name  age  height_cm  weight_kgs  positions   nationality  \
# 0            L. Messi   31     170.18        72.1          1     Argentina
# 1          C. Eriksen   27     154.94        76.2          2       Denmark
# 2            P. Pogba   25     190.50        83.9          2        France
# 3          L. Insigne   27     162.56        59.0          1         Italy
# 4        K. Koulibaly   27     187.96        88.9          3       Senegal
# ...               ...  ...        ...         ...        ...           ...
# 17949     R. McKenzie   25     175.26        74.8          2      Scotland
# 17950       M. Sipľak   23     182.88        79.8          3      Slovakia
# 17951      J. Bekkema   22     185.42        89.8          4   Netherlands
# 17952      A. Al Yami   21     175.26        64.9          1  Saudi Arabia
# 17953  Júnior Brumado   19     190.50        79.8          1        Brazil
#
#        overall_rating  potential   value_euro  wage_euro  preferred_foot  \
# 0                  94         94  110500000.0   565000.0               1
# 1                  88         89   69500000.0   205000.0               1
# 2                  88         91   73000000.0   255000.0               1
# 3                  88         88   62000000.0   165000.0               1
# 4                  88         91   60000000.0   135000.0               1
# ...               ...        ...          ...        ...             ...
# 17949              67         70     975000.0     3000.0               1
# 17950              59         67     190000.0     1000.0               1
# 17951              59         67     170000.0     1000.0               1
# 17952              59         71     280000.0     4000.0               1
# 17953              59         75     325000.0     2000.0               1
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 0             94.875      76.6         84.000000             27.25
# 1             86.125      69.8         78.166667             48.50
# 2             82.625      81.6         82.250000             65.25
# 3             88.750      70.4         72.500000             30.75
# 4             57.625      79.0         43.250000             88.50
# ...              ...       ...               ...               ...
# 17949         67.625      77.0         57.166667             29.75
# 17950         47.375      68.8         38.666667             58.00
# 17951         28.750      36.0         14.833333             11.00
# 17952         57.000      67.0         48.916667             16.50
# 17953         53.375      64.6         48.500000             23.75
#
#        player_rating
# 0           4.333333
# 1           4.000000
# 2           4.333333
# 3           3.666667
# 4           2.666667
# ...              ...
# 17949       2.333333
# 17950       2.000000
# 17951       1.000000
# 17952       2.666667
# 17953       2.333333
#
# [17699 rows x 16 columns]

# %% [markdown]
# Assuming 'Overall rating' as target variable and other columns as features.

# %%
data.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kgs', 'positions', 'nationality',
#        'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'player_skills', 'physique', 'offensive_skills',
#        'defensive_skills', 'player_rating'],
#       dtype='object')

# %%
features = ['age', 'height_cm', 'weight_kgs', 'positions', 'potential', 'value_euro', 'wage_euro',
            'preferred_foot', 'player_skills', 'physique','offensive_skills','defensive_skills', 'player_rating']

# %%
target = 'overall_rating'

# %%
x = data[features]
x
# Out:
#        age  height_cm  weight_kgs  positions  potential   value_euro  \
# 0       31     170.18        72.1          1         94  110500000.0
# 1       27     154.94        76.2          2         89   69500000.0
# 2       25     190.50        83.9          2         91   73000000.0
# 3       27     162.56        59.0          1         88   62000000.0
# 4       27     187.96        88.9          3         91   60000000.0
# ...    ...        ...         ...        ...        ...          ...
# 17949   25     175.26        74.8          2         70     975000.0
# 17950   23     182.88        79.8          3         67     190000.0
# 17951   22     185.42        89.8          4         67     170000.0
# 17952   21     175.26        64.9          1         71     280000.0
# 17953   19     190.50        79.8          1         75     325000.0
#
#        wage_euro  preferred_foot  player_skills  physique  offensive_skills  \
# 0       565000.0               1         94.875      76.6         84.000000
# 1       205000.0               1         86.125      69.8         78.166667
# 2       255000.0               1         82.625      81.6         82.250000
# 3       165000.0               1         88.750      70.4         72.500000
# 4       135000.0               1         57.625      79.0         43.250000
# ...          ...             ...            ...       ...               ...
# 17949     3000.0               1         67.625      77.0         57.166667
# 17950     1000.0               1         47.375      68.8         38.666667
# 17951     1000.0               1         28.750      36.0         14.833333
# 17952     4000.0               1         57.000      67.0         48.916667
# 17953     2000.0               1         53.375      64.6         48.500000
#
#        defensive_skills  player_rating
# 0                 27.25       4.333333
# 1                 48.50       4.000000
# 2                 65.25       4.333333
# 3                 30.75       3.666667
# 4                 88.50       2.666667
# ...                 ...            ...
# 17949             29.75       2.333333
# 17950             58.00       2.000000
# 17951             11.00       1.000000
# 17952             16.50       2.666667
# 17953             23.75       2.333333
#
# [17699 rows x 13 columns]

# %%
y = data[target]
y
# Out:
# 0        94
# 1        88
# 2        88
# 3        88
# 4        88
#          ..
# 17949    67
# 17950    59
# 17951    59
# 17952    59
# 17953    59
# Name: overall_rating, Length: 17699, dtype: int64

# %% [markdown]
# importing train_test_split for splitting training and testing datas.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# importing needed machine learning algorithms.

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Checking score on trained  linear model.

# %%
linear_model.score(x_train,y_train)
# Out:
# 0.8960636132379047

# %% [markdown]
# Checking score on tested linear model.

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.8919916253657683

# %%
linear_pred = linear_model.predict(x_test)

# %% [markdown]
# Comparing linear model Orginal and Predicted values.

# %%
linear_compare = pd.DataFrame({'Orginal values':y_test,'Predicted values':linear_pred})
linear_compare.sample(10)
# Out:
#        Orginal values  Predicted values
# 5067               51         55.956877
# 8607               63         64.642201
# 4829               50         54.826759
# 5195               52         53.080341
# 7844               61         60.158354
# 4146               59         62.095081
# 8302               62         66.060688
# 1478               70         67.305373
# 17302              77         76.360190
# 15907              73         74.371474

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=8)
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=8)

# %%
knn_model.score(x_train,y_train)
# Out:
# 0.94629129083154

# %%
knn_model.score(x_test,y_test)
# Out:
# 0.9317282168072503

# %%
knn_pred = knn_model.predict(x_test)

# %% [markdown]
# Comparing KNN model Orginal and predicted values.

# %%
knn_compare = pd.DataFrame({'Orginal Values':y_test,'Predicted Values':knn_pred})
knn_compare.sample(10)
# Out:
#        Orginal Values  Predicted Values
# 9785               64            64.500
# 5794               56            54.250
# 2034               68            70.750
# 11951              67            67.625
# 1995               68            66.500
# 7429               60            60.625
# 10439              65            66.625
# 12717              68            49.875
# 4042               60            60.750
# 3310               63            62.500

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_model.score(x_train,y_train)
# Out:
# 1.0

# %%
dt_model.score(x_test,y_test)
# Out:
# 0.993885912392942

# %%
dt_pred = dt_model.predict(x_test)

# %% [markdown]
# Comparing Decision Tree Model Orginal and predicted values.

# %%
dt_compare = pd.DataFrame({'Orginal Values':y_test,'Predicted Values':dt_pred})
dt_compare.sample(10)
# Out:
#        Orginal Values  Predicted Values
# 2976               64              64.0
# 13199              69              68.0
# 7824               61              61.0
# 11064              66              66.0
# 11871              67              66.0
# 4550               55              55.0
# 10908              66              66.0
# 17497              79              80.0
# 2584               66              66.0
# 11556              66              66.0

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor()
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_model.score(x_train,y_train)
# Out:
# 0.999570200957138

# %%
rf_model.score(x_test,y_test)
# Out:
# 0.9969360217526433

# %%
rf_pred = rf_model.predict(x_test)

# %% [markdown]
# Comparing Random Forest Model Orginal and predicted values.

# %%
rf_compare = pd.DataFrame({'Orginal Values':y_test,'Predicted Values':rf_pred})
rf_compare.sample(10)
# Out:
#        Orginal Values  Predicted Values
# 14855              71             71.07
# 14585              71             71.00
# 17278              77             76.89
# 13508              69             69.00
# 8289               62             61.93
# 1627               69             68.89
# 11254              66             66.00
# 11095              66             65.66
# 27                 87             86.71
# 16140              74             74.00

# %%
data.sample(10)
# Out:
#                name  age  height_cm  weight_kgs  positions  nationality  \
# 11127       A. Sané   26     182.88        73.0          1      Senegal
# 1989       D. Badji   26     182.88        78.9          1      Senegal
# 10891     A. Winter   32     152.40        74.8          2  Switzerland
# 10702     J. Clarke   27     182.88        71.2          3      England
# 6490    S. Karweina   19     172.72        64.9          1      Germany
# 5840   Yang Wanshun   23     152.40        74.8          1     China PR
# 9132    I. Sirelius   31     152.40        78.0          1       Sweden
# 4481        Yang Ke   29     182.88        78.0          2     China PR
# 2413      K. Larsen   27     182.88        73.9          2       Norway
# 15794      L. Ulloa   32     187.96        88.9          1    Argentina
#
#        overall_rating  potential  value_euro  wage_euro  preferred_foot  \
# 11127              66         69    825000.0     3000.0               1
# 1989               68         71   1100000.0     4000.0               1
# 10891              66         66    575000.0     5000.0               1
# 10702              65         65    450000.0     3000.0               1
# 6490               58         69    210000.0     1000.0               1
# 5840               56         65    140000.0     2000.0               1
# 9132               63         63    350000.0     1000.0               1
# 4481               56         56     90000.0     2000.0               1
# 2413               66         66    700000.0     2000.0               1
# 15794              73         73   3600000.0    26000.0               1
#
#        player_skills  physique  offensive_skills  defensive_skills  \
# 11127         58.875      66.0         58.083333             21.00
# 1989          60.000      79.0         55.333333             33.00
# 10891         63.250      75.0         58.416667             46.75
# 10702         57.000      72.4         45.083333             65.75
# 6490          56.125      59.2         47.916667             16.50
# 5840          56.000      66.2         49.583333             50.00
# 9132          61.000      66.8         53.833333             41.50
# 4481          54.500      58.2         46.083333             25.75
# 2413          67.000      67.0         55.166667             32.50
# 15794         64.625      60.8         68.916667             45.25
#
#        player_rating
# 11127       1.666667
# 1989        2.000000
# 10891       1.666667
# 10702       2.000000
# 6490        2.000000
# 5840        1.666667
# 9132        2.000000
# 4481        2.000000
# 2413        2.666667
# 15794       2.000000

# %% [markdown]
# # Hyper parameter tuning - GridSearch

# %%
from sklearn.model_selection import GridSearchCV

# %%
gridsearch_cv = GridSearchCV(rf_model,{'n_estimators':[24,35,41,50,65,72]},cv=5,return_train_score=True)

# %%
gridsearch_cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'n_estimators': [24, 35, 41, 50, 65, 72]},
#              return_train_score=True)

# %%
pd.DataFrame(gridsearch_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.457753      0.212674         0.016426        0.000571
# 1       2.108958      0.287654         0.027089        0.004198
# 2       2.533609      0.235639         0.026036        0.002152
# 3       2.938847      0.200958         0.031170        0.003917
# 4       3.895209      0.154921         0.042577        0.002310
# 5       4.261904      0.217779         0.046964        0.005059
#
#    param_n_estimators                params  split0_test_score  \
# 0                  24  {'n_estimators': 24}           0.996625
# 1                  35  {'n_estimators': 35}           0.996573
# 2                  41  {'n_estimators': 41}           0.996790
# 3                  50  {'n_estimators': 50}           0.996725
# 4                  65  {'n_estimators': 65}           0.996693
# 5                  72  {'n_estimators': 72}           0.996789
#
#    split1_test_score  split2_test_score  split3_test_score  ...  \
# 0           0.996378           0.996474           0.996413  ...
# 1           0.996469           0.996407           0.996362  ...
# 2           0.996490           0.996432           0.996495  ...
# 3           0.996449           0.996513           0.996439  ...
# 4           0.996576           0.996594           0.996491  ...
# 5           0.996468           0.996551           0.996461  ...
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.996503        0.000105                6            0.999442
# 1         0.996519        0.000149                5            0.999478
# 2         0.996582        0.000139                4            0.999487
# 3         0.996590        0.000156                3            0.999516
# 4         0.996637        0.000117                1            0.999525
# 5         0.996617        0.000155                2            0.999523
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0            0.999447            0.999454            0.999438
# 1            0.999475            0.999501            0.999487
# 2            0.999486            0.999505            0.999490
# 3            0.999497            0.999515            0.999513
# 4            0.999503            0.999518            0.999519
# 5            0.999506            0.999545            0.999521
#
#    split4_train_score  mean_train_score  std_train_score
# 0            0.999429          0.999442         0.000008
# 1            0.999477          0.999483         0.000010
# 2            0.999477          0.999489         0.000009
# 3            0.999502          0.999509         0.000008
# 4            0.999509          0.999515         0.000008
# 5            0.999508          0.999521         0.000014
#
# [6 rows x 21 columns]

# %%
gridsearch_cv.score(x_test,y_test)
# Out:
# 0.9969936616418065

# %%
gridsearch_cv.best_params_
# Out:
# {'n_estimators': 65}

# %%
gridsearch_cv.best_score_
# Out:
# np.float64(0.9966372143007863)

# %%
x.sample(5)
# Out:
#        age  height_cm  weight_kgs  positions  potential  value_euro  \
# 14139   26     187.96        83.9          1         73   2200000.0
# 14737   38     185.42        79.8          3         71    325000.0
# 7031    19     152.40        71.2          2         71    325000.0
# 15598   25     187.96        83.0          1         76   4100000.0
# 14462   31     152.40        76.2          4         70   1100000.0
#
#        wage_euro  preferred_foot  player_skills  physique  offensive_skills  \
# 14139     2000.0               1         59.875      71.2         64.333333
# 14737     3000.0               1         49.250      51.0         55.833333
# 7031      1000.0               1         58.375      63.4         46.333333
# 15598    18000.0               1         64.750      73.2         62.833333
# 14462    11000.0               1         42.375      55.2         12.833333
#
#        defensive_skills  player_rating
# 14139             40.25       2.000000
# 14737             72.75       2.333333
# 7031              23.00       2.333333
# 15598             22.00       2.333333
# 14462              9.75       1.666667

# %%
x.columns
# Out:
# Index(['age', 'height_cm', 'weight_kgs', 'positions', 'potential',
#        'value_euro', 'wage_euro', 'preferred_foot', 'player_skills',
#        'physique', 'offensive_skills', 'defensive_skills', 'player_rating'],
#       dtype='object')

# %% [markdown]
# Getting input from user and predicting the overall rating.

# %% [markdown]
# # User Input Method

# %%
player_age = input('Enter the age of player: ')
player_height = input('Enter the height(cm) of player: ')
player_weight = input('Enter the weight(kg) of player: ')
player_position = input("Enter the players position: ['Forward-1','Midfielder-2','Defender-3','GoalKeeper-4']")
player_potential = input('Enter the potential of player(out of 100): ')
player_value = input('Enter the value(euro) of player: ')
player_wage = input('Enter the wage(euro) of player: ')
player_foot = input("Enter preferred foot of player: ['Left-1','Right-1']")
player_skill = input('Enter the skill of player(out of 100): ')
player_physique = input('Enter the physique of player(out of 100): ')
player_off_skill = input('Enter the offensive skill of player(out of 100): ')
player_def_skill = input('Enter the defensive skill of player(out of 100): ')
player_rating = input('Enter the rating of player(out of 5): ')
# Out:
# Enter the height(cm) of player: 21

# %%
rf_model.predict([[player_age,player_height,player_weight,player_position,player_potential,player_value,player_wage,player_foot,player_skill,player_physique,player_off_skill,player_def_skill,player_rating]])

# %%
x_test.tail(5)

# %%
y_test.tail(5)
